# %% [markdown]
# ### Verificar GPU

# %%
import tensorflow as tf

# Verificar dispositivos disponíveis
devices = tf.config.list_physical_devices()
print("Dispositivos disponíveis:")
for device in devices:
    print(f"- {device.device_type}: {device.name}")

# Verificar se a GPU está sendo utilizada
if tf.config.list_physical_devices('GPU'):
    print("\nGPU está disponível e será utilizada pelo TensorFlow!")
    print(f"Dispositivo GPU detectado: {tf.test.gpu_device_name()}")
else:
    print("\nGPU não está disponível. O TensorFlow está utilizando a CPU.")
# Out:
# Dispositivos disponíveis:
# - CPU: /physical_device:CPU:0
# - GPU: /physical_device:GPU:0
#
# GPU está disponível e será utilizada pelo TensorFlow!
# Dispositivo GPU detectado: /device:GPU:0

# %% [markdown]
# ### FLUXO

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input as preprocess_efficientnet
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
import tensorflow as tf

# Carregar os dados
def load_data(train_dir, val_dir, test_dir, target_size=(512, 512), batch_size=8, preprocess_fn=None):
    train_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_fn,
        horizontal_flip=True,
        brightness_range=(0.8, 1.2)
    )
    val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_fn)
    
    train_data = train_datagen.flow_from_directory(
        train_dir, target_size=target_size, batch_size=batch_size, class_mode='categorical', shuffle=True
    )
    val_data = val_test_datagen.flow_from_directory(
        val_dir, target_size=target_size, batch_size=batch_size, class_mode='categorical', shuffle=True
    )
    test_data = val_test_datagen.flow_from_directory(
        test_dir, target_size=target_size, batch_size=batch_size, class_mode='categorical', shuffle=False
    )
    return train_data, val_data, test_data

# Construir o modelo
def build_model(base_model_fn, num_classes, trainable_layers=0):
    base_model = base_model_fn(weights='imagenet', include_top=False, input_shape=(512, 512, 3))
    for layer in base_model.layers[:-trainable_layers]:
        layer.trainable = False
    
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(0.5),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# Função para calcular a Focal Loss
def focal_loss(gamma=2.0, alpha=0.25):
    def loss_fn(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        pt = tf.reduce_sum(y_true * y_pred, axis=-1)
        return alpha * tf.pow(1. - pt, gamma) * ce_loss
    return loss_fn

# Função para plotar curvas de treinamento
def plot_history(history, title=None):
    plt.figure(figsize=(12, 4))
    
    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='train loss')
    plt.plot(history.history['val_loss'], label='val loss')
    plt.title('Loss')
    if title:
        plt.suptitle(title)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='train acc')
    plt.plot(history.history['val_accuracy'], label='val acc')
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Função para treinar o modelo (retorna history)
def train_model(model, train_data, val_data, cnn_name, stage, class_weight=None, learning_rate=0.0001, epochs=100):
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=focal_loss(alpha=0.25, gamma=2),
        metrics=['accuracy']
    )
    
    callbacks = [
        EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-6, verbose=1),
        ModelCheckpoint(
            filepath=f"{cnn_name}_{stage}_best_model_512.h5",
            monitor='val_loss', mode='min',
            save_best_only=False, save_weights_only=True, verbose=1
        )
    ]
    
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        callbacks=callbacks,
        class_weight=class_weight,
        verbose=1
    )
    return history

# Avaliação do modelo
def evaluate_model(model, test_data, class_indices, cnn_name, stage):
    print(f"Avaliando {cnn_name} ({stage}) no conjunto de teste...")
    predictions = model.predict(test_data, verbose=1)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_data.classes
    report = classification_report(true_classes, predicted_classes, target_names=list(class_indices.keys()))
    print(report)

# Função principal modificada para EfficientNetB3
def main(train_dir, val_dir, test_dir, cnn_name, output_file):
    train_data, val_data, test_data = load_data(
        train_dir, val_dir, test_dir, preprocess_fn=preprocess_efficientnet
    )
    print("Classes e índices do modelo:", train_data.class_indices)

    num_classes = len(train_data.class_indices)
    class_weight = compute_class_weight('balanced', classes=np.arange(num_classes), y=train_data.classes)
    class_weight_dict = dict(enumerate(class_weight))
    
    # Aumentar peso da classe "ovelha"
    ovelha_label = train_data.class_indices.get("ovelha")
    if ovelha_label is not None:
        class_weight_dict[ovelha_label] *= 2.0
    
    print("Class Weights Ajustados:", class_weight_dict)

    # Transfer learning
    model = build_model(EfficientNetB3, num_classes, trainable_layers=0)
    history_tl = train_model(
        model, train_data, val_data, cnn_name,
        "transfer_learning", class_weight=class_weight_dict, epochs=100
    )
    plot_history(history_tl, title=f"{cnn_name} – Transfer Learning")
    
    # Fine tuning (destravando metade das camadas)
    total_layers = len(EfficientNetB3(weights='imagenet', include_top=False).layers)
    model = build_model(EfficientNetB3, num_classes, trainable_layers=total_layers // 2)
    history_ft = train_model(
        model, train_data, val_data, cnn_name,
        "fine_tuning", class_weight=class_weight_dict, epochs=100
    )
    plot_history(history_ft, title=f"{cnn_name} – Fine Tuning")
    
    # Avaliação
    evaluate_model(model, test_data, train_data.class_indices, cnn_name, "fine_tuning")

# Executa o script principal
if __name__ == "__main__":
    main("train", "val", "test", "EfficientNetB3", "EfficientNetB3_results_512.xlsx")
# Out:
# Found 3142 images belonging to 3 classes.
# Found 827 images belonging to 3 classes.
# Found 823 images belonging to 3 classes.
# Classes e índices do modelo: {'fundo': 0, 'notovelha': 1, 'ovelha': 2}
# Class Weights Ajustados: {0: 1.7602240896358543, 1: 0.5867413632119515, 2: 2.748906386701662}
# Epoch 1/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.6910
# Epoch 1: saving model to EfficientNetB3_transfer_learning_best_model_512.h5
# 393/393 [==============================] - 207s 489ms/step - loss: 0.0713 - accuracy: 0.6910 - val_loss: 0.0339 - val_accuracy: 0.8235 - lr: 1.0000e-04
# Epoch 2/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.8603
# Epoch 2: saving model to EfficientNetB3_transfer_learning_best_model_512.h5
# 393/393 [==============================] - 189s 482ms/step - loss: 0.0301 - accuracy: 0.8603 - val_loss: 0.0135 - val_accuracy: 0.9287 - lr: 1.0000e-04
# Epoch 3/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9153
# Epoch 3: saving model to EfficientNetB3_transfer_learning_best_model_512.h5
# 393/393 [==============================] - 189s
100
# 393/393 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.8679
# Epoch 2: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 215ms/step - loss: 0.0261 - accuracy: 0.8679 - val_loss: 0.0130 - val_accuracy: 0.9347 - lr: 1.0000e-04
# Epoch 3/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9048
# Epoch 3: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 84s 214ms/step - loss: 0.0182 - accuracy: 0.9048 - val_loss: 0.0181 - val_accuracy: 0.9093 - lr: 1.0000e-04
# Epoch 4/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9309
# Epoch 4: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 84s 215ms/step - loss: 0.0143 - accuracy: 0.9309 - val_loss: 0.0136 - val_accuracy: 0.9504 - lr: 1.0000e-04
# Epoch 5/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9545
# Epoch 5: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 84s 215ms/step - loss: 0.0106 - accuracy: 0.9545 - val_loss: 0.0114 - val_accuracy: 0.9577 - lr: 1.0000e-04
# Epoch 6/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9583
# Epoch 6: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 215ms/step - loss: 0.0089 - accuracy: 0.9583 - val_loss: 0.0064 - val_accuracy: 0.9710 - lr: 1.0000e-04
# Epoch 7/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9701
# Epoch 7: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0073 - accuracy: 0.9701 - val_loss: 0.0092 - val_accuracy: 0.9577 - lr: 1.0000e-04
# Epoch 8/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9704
# Epoch 8: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0059 - accuracy: 0.9704 - val_loss: 0.0105 - val_accuracy: 0.9553 - lr: 1.0000e-04
# Epoch 9/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9771
# Epoch 9: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0051 - accuracy: 0.9771 - val_loss: 0.0120 - val_accuracy: 0.9613 - lr: 1.0000e-04
# Epoch 10/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9637
# Epoch 10: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0075 - accuracy: 0.9637 - val_loss: 0.0137 - val_accuracy: 0.9686 - lr: 1.0000e-04
# Epoch 11/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9749
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 11: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 216ms/step - loss: 0.0062 - accuracy: 0.9749 - val_loss: 0.0257 - val_accuracy: 0.9359 - lr: 1.0000e-04
# Epoch 12/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9644
# Epoch 12: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 216ms/step - loss: 0.0068 - accuracy: 0.9644 - val_loss: 0.0150 - val_accuracy: 0.9468 - lr: 1.0000e-05
# Epoch 13/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9764
# Epoch 13: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 216ms/step - loss: 0.0045 - accuracy: 0.9764 - val_loss: 0.0139 - val_accuracy: 0.9492 - lr: 1.0000e-05
# Epoch 14/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9812
# Epoch 14: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0036 - accuracy: 0.9812 - val_loss: 0.0122 - val_accuracy: 0.9516 - lr: 1.0000e-05
# Epoch 15/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9879
# Epoch 15: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0021 - accuracy: 0.9879 - val_loss: 0.0116 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 16/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9898
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 16: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0019 - accuracy: 0.9898 - val_loss: 0.0104 - val_accuracy: 0.9625 - lr: 1.0000e-05
# Epoch 17/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9914
# Epoch 17: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0019 - accuracy: 0.9914 - val_loss: 0.0103 - val_accuracy: 0.9625 - lr: 1.0000e-06
# Epoch 18/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9905
# Epoch 18: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 86s 217ms/step - loss: 0.0017 - accuracy: 0.9905 - val_loss: 0.0106 - val_accuracy: 0.9613 - lr: 1.0000e-06
# Epoch 19/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9914
# Epoch 19: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0017 - accuracy: 0.9914 - val_loss: 0.0104 - val_accuracy: 0.9613 - lr: 1.0000e-06
# Epoch 20/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9901
# Epoch 20: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0019 - accuracy: 0.9901 - val_loss: 0.0107 - val_accuracy: 0.9625 - lr: 1.0000e-06
# Epoch 21/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9927
# Epoch 21: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 216ms/step - loss: 0.0016 - accuracy: 0.9927 - val_loss: 0.0106 - val_accuracy: 0.9649 - lr: 1.0000e-06
# Epoch 22/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9927
# Epoch 22: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 86s 217ms/step - loss: 0.0017 - accuracy: 0.9927 - val_loss: 0.0110 - val_accuracy: 0.9625 - lr: 1.0000e-06
# Epoch 23/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9905
# Epoch 23: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 216ms/step - loss: 0.0022 - accuracy: 0.9905 - val_loss: 0.0112 - val_accuracy: 0.9601 - lr: 1.0000e-06
# Epoch 24/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9885
# Epoch 24: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 216ms/step - loss: 0.0019 - accuracy: 0.9885 - val_loss: 0.0108 - val_accuracy: 0.9661 - lr: 1.0000e-06
# Epoch 25/100
# 393/393 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9898
# Epoch 25: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 215ms/step - loss: 0.0019 - accuracy: 0.9898 - val_loss: 0.0110 - val_accuracy: 0.9625 - lr: 1.0000e-06
# Epoch 26/100
# Restoring model weights from the end of the best epoch: 6. 0.0017 - accuracy: 0.9908
#
# Epoch 26: saving model to EfficientNetB3_fine_tuning_best_model_512.h5
# 393/393 [==============================] - 85s 217ms/step - loss: 0.0017 - accuracy: 0.9908 - val_loss: 0.0107 - val_accuracy: 0.9625 - lr: 1.0000e-06
# Epoch 26: early stopping
# Avaliando EfficientNetB3 (fine_tuning) no conjunto de teste...
# 103/103 [==============================] - 22s 199ms/step
#               precision    recall  f1-score   support
#
#        fundo       0.90      0.98      0.94       206
#    notovelha       0.97      0.91      0.94       433
#       ovelha       0.93      0.96      0.94       184
#
#     accuracy                           0.94       823
#    macro avg       0.93      0.95      0.94       823
# weighted avg       0.94      0.94      0.94       823

# %% [markdown]
# ## AVALIAÇÃO TESTE

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.applications.efficientnet import preprocess_input as preprocess_efficientnet
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf

# Focal Loss
def focal_loss(gamma=2., alpha=0.25):
    def loss_fn(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        pt = tf.reduce_sum(y_true * y_pred, axis=-1)
        return alpha * tf.pow(1. - pt, gamma) * ce_loss
    return loss_fn

# Carregar dados
def load_data(test_dir, target_size=(256, 256), batch_size=8, preprocess_fn=None):
    test_datagen = ImageDataGenerator(preprocessing_function=preprocess_fn)
    return test_datagen.flow_from_directory(
        test_dir, target_size=target_size, batch_size=batch_size, class_mode='categorical', shuffle=False
    )

# Reconstruir o modelo Sequential (como no script de treinamento)
def build_model(base_model_fn, num_classes, trainable_layers=0):
    base_model = base_model_fn(weights='imagenet', include_top=False, input_shape=(256, 256, 3))
    for layer in base_model.layers[:-trainable_layers]:
        layer.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(0.5),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# Avaliar modelo
def evaluate_model(model_path, test_data, model_name, trainable_layers=0):
    num_classes = test_data.num_classes
    class_names = list(test_data.class_indices.keys())

    print(f"🔹 Reconstruindo e carregando pesos do modelo: {model_name}")
    model = build_model(EfficientNetB7, num_classes, trainable_layers=trainable_layers)
    model.compile(optimizer='adam', loss=focal_loss(), metrics=['accuracy'])
    model.load_weights(model_path)

    print(f"🔹 Realizando previsões...")
    predictions = model.predict(test_data, verbose=1)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_data.classes

    # Relatório
    report = classification_report(true_classes, predicted_classes, target_names=class_names, output_dict=True)
    print(f"\n📌 Relatório de Classificação - {model_name}:")
    print(classification_report(true_classes, predicted_classes, target_names=class_names))

    # Matriz de confusão
    cm = confusion_matrix(true_classes, predicted_classes)
    print(f"\n📌 Matriz de Confusão - {model_name}:\n", cm)

    # Gráfico
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
    plt.title(f"Matriz de Confusão - {model_name}")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)
    for i in range(len(class_names)):
        for j in range(len(class_names)):
            plt.text(j, i, str(cm[i, j]), ha="center", va="center", color="red")
    plt.xlabel("Predito")
    plt.ylabel("Verdadeiro")
    plt.tight_layout()
    plt.show()

    # Retornar métricas
    weighted_avg = report['weighted avg']
    return {
        'Precision': weighted_avg['precision'],
        'Recall': weighted_avg['recall'],
        'F1-Score': weighted_avg['f1-score'],
        'Accuracy': report['accuracy']
    }

# Avaliação
test_dir = "test"
test_data = load_data(test_dir, preprocess_fn=preprocess_efficientnet)

# Caminhos dos pesos salvos
metrics_tl = evaluate_model("EfficientNetB7_transfer_learning_best_model_256.h5", test_data, "Transfer Learning", trainable_layers=0)
metrics_ft = evaluate_model("EfficientNetB7_fine_tuning_best_model_256.h5", test_data, "Fine Tuning", trainable_layers=len(EfficientNetB7(weights='imagenet', include_top=False).layers)//2)
# Out:
# Found 823 images belonging to 3 classes.
# 🔹 Reconstruindo e carregando pesos do modelo: Transfer Learning
# 🔹 Realizando previsões...
# 103/103 [==============================] - 23s 171ms/step
#
# 📌 Relatório de Classificação - Transfer Learning:
#               precision    recall  f1-score   support
#
#        fundo       0.98      0.98      0.98       206
#    notovelha       0.95      0.97      0.96       433
#       ovelha       0.95      0.91      0.93       184
#
#     accuracy                           0.96       823
#    macro avg       0.96      0.95      0.96       823
# weighted avg       0.96      0.96      0.96       823
#
#
# 📌 Matriz de Confusão - Transfer Learning:
#  [[202   4   0]
#  [  5 419   9]
#  [  0  16 168]]
# 🔹 Reconstruindo e carregando pesos do modelo: Fine Tuning
# 🔹 Realizando previsões...
# 103/103 [==============================] - 17s 111ms/step
#
# 📌 Relatório de Classificação - Fine Tuning:
#               precision    recall  f1-score   support
#
#        fundo       0.93      0.98      0.95       206
#    notovelha       0.97      0.89      0.93       433
#       ovelha       0.85      0.96      0.90       184
#
#     accuracy                           0.93       823
#    macro avg       0.92      0.94      0.93       823
# weighted avg       0.93      0.93      0.93       823
#
#
# 📌 Matriz de Confusão - Fine Tuning:
#  [[201   5   0]
#  [ 14 387  32]
#  [  0   7 177]]

# %%
import os
import shutil
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.efficientnet import preprocess_input as preprocess_efficientnet
import tensorflow as tf

# Redefinir a função focal_loss
def focal_loss(gamma=2., alpha=0.25):
    def loss_fn(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        pt = tf.reduce_sum(y_true * y_pred, axis=-1)
        focal_loss = alpha * tf.pow(1. - pt, gamma) * ce_loss
        return focal_loss
    return loss_fn

# Função para classificar e organizar as imagens com um intervalo de confiança
def classify_images_by_index(model_path, test_dir, target_size=(512, 512), preprocess_fn=None, confidence_threshold=0.7):
    """
    Usa o modelo para classificar imagens e organiza por índices numéricos com base em um intervalo de confiança.
    """
    print(f"Carregando o modelo salvo de {model_path}...")
    # Carregar o modelo com a função de perda personalizada
    model = load_model(model_path, custom_objects={'loss_fn': focal_loss()})

    # Iterar pelos subdiretórios principais dentro do diretório de teste
    for subdir in os.listdir(test_dir):
        subdir_path = os.path.join(test_dir, subdir)

        # Ignorar se não for um diretório
        if not os.path.isdir(subdir_path):
            continue

        # Caminho da subpasta 'images'
        images_path = os.path.join(subdir_path, "images")
        if not os.path.exists(images_path):
            print(f"Subpasta 'images' não encontrada em {subdir_path}, ignorando...")
            continue

        print(f"Processando diretório: {subdir}")

        # Criar pastas para cada índice numérico de classe (0, 1, 2, ...) e uma pasta "uncertain" para previsões abaixo do limite
        class_indices = [0, 1, 2]  # Ajuste conforme o número de classes do modelo
        for class_index in class_indices:
            class_folder = os.path.join(subdir_path, str(class_index))
            os.makedirs(class_folder, exist_ok=True)
        uncertain_folder = os.path.join(subdir_path, "uncertain")
        os.makedirs(uncertain_folder, exist_ok=True)

        # Processar imagens dentro da subpasta 'images'
        for image_name in os.listdir(images_path):
            image_path = os.path.join(images_path, image_name)

            # Ignorar se não for um arquivo
            if not os.path.isfile(image_path):
                continue

            try:
                # Carregar e preprocessar a imagem
                img = load_img(image_path, target_size=target_size)
                img_array = img_to_array(img)
                img_array = preprocess_fn(img_array)
                img_array = np.expand_dims(img_array, axis=0)

                # Fazer a previsão
                prediction = model.predict(img_array, verbose=0)
                predicted_class = np.argmax(prediction, axis=1)[0]
                confidence = prediction[0][predicted_class]

                # Verificar se a confiança está acima do limite
                if confidence >= confidence_threshold:
                    # Mover a imagem para a pasta correspondente
                    target_folder = os.path.join(subdir_path, str(predicted_class))
                    shutil.move(image_path, os.path.join(target_folder, image_name))
                    print(f"Imagem {image_name} classificada como {predicted_class} com confiança {confidence:.2f} e movida para {target_folder}")
                else:
                    # Mover a imagem para a pasta "uncertain"
                    shutil.move(image_path, os.path.join(uncertain_folder, image_name))
                    print(f"Imagem {image_name} classificada como incerta (confiança {confidence:.2f}) e movida para {uncertain_folder}")
            
            except Exception as e:
                print(f"Erro ao processar {image_path}: {e}")

# Caminhos necessários
model_path = "EfficientNetB3_fine_tuning_best_model_512.h5"  # Caminho do modelo salvo
test_dir = "teste_512"  # Diretório raiz das imagens
preprocess_fn = preprocess_efficientnet  # Função de pré-processamento do modelo
confidence_threshold = 0.7  # Intervalo de confiança (70%)

# Classificar imagens usando índices numéricos
classify_images_by_index(model_path, test_dir, preprocess_fn=preprocess_fn, confidence_threshold=confidence_threshold)
# Out:
# Carregando o modelo salvo de EfficientNetB3_fine_tuning_best_model_512.h5...
# Processando diretório: C1_03
# Imagem 10_png.rf.a0eabf57066de56d0752ab5cee7d3efc.jpg classificada como 1 com confiança 0.94 e movida para teste_512\C1_03\1
# Imagem 11_png.rf.b3f16018ebdaccbf3089c488471b8e28.jpg classificada como 2 com confiança 0.95 e movida para teste_512\C1_03\2
jpg classificada como 0 com confiança 0.97 e movida para teste_512\C1_40\0
# Imagem 5_png.rf.54da4a9ef74d12252b3335e7e3583989.jpg classificada como 0 com confiança 0.97 e movida para teste_512\C1_40\0
# Imagem 6_png.rf.3a3970ad71b594ccd7137846d8bca9ce.jpg classificada como 0 com confiança 0.96 e movida para teste_512\C1_40\0
# Imagem 7_png.rf.ecdc20ea16486442936fa764e4842e07.jpg classificada como 0 com confiança 0.97 e movida para teste_512\C1_40\0
# Imagem 8_png.rf.2b6c7ef1eacb0f72f3afc24c7c37ad19.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C1_40\1
# Imagem 9_png.rf.9eacd4b2f1ec38c1cb02fe004af2fbc3.jpg classificada como incerta (confiança 0.59) e movida para teste_512\C1_40\uncertain
# Processando diretório: C2_03
# Imagem image_0720_left_bottom_png.rf.a7b8f8e37100f15413c9a3f84e727873.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_03\1
# Imagem image_0721_left_bottom_png.rf.c6b62b1486065a94abcbf776a061ed6c.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_03\1
# Imagem image_0722_left_bottom_png.rf.0473cbd63c77d0959f51394f890676cb.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_03\1
# Imagem image_0723_left_bottom_png.rf.feca2e967d4881515bf47163f3861607.jpg classificada como 1 com confiança 0.96 e movida para teste_512\C2_03\1
# Imagem image_0724_left_bottom_png.rf.6348f5bef172c5e9974944d4d358f029.jpg classificada como 1 com confiança 0.95 e movida para teste_512\C2_03\1
# Imagem image_0725_left_bottom_png.rf.eecd29943a7311ebf5c4231e08ca3893.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_03\1
# Imagem image_0726_left_bottom_png.rf.11aadea3e96b781a4d0ab3e80edd666e.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_03\1
# Imagem image_0727_left_bottom_png.rf.56d92400b96a3b684729b60f1712bb6d.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_03\1
# Imagem image_0728_left_bottom_png.rf.890e5330210dcf077c10a052bd92a4f0.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_03\1
# Imagem image_0729_left_bottom_png.rf.4813e48b0bcfdeef303876418a5e05ed.jpg classificada como 1 com confiança 0.96 e movida para teste_512\C2_03\1
# Imagem image_0730_left_bottom_png.rf.af0937691064aad252b9db2f9dfb86ce.jpg classificada como 1 com confiança 0.96 e movida para teste_512\C2_03\1
# Imagem image_0731_left_bottom_png.rf.b2c38c3a340d22ed2f8c3114d2b0fc79.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_03\1
# Imagem image_0732_left_bottom_png.rf.c9d44445526d2a17bcb3ab40a1106d6f.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_03\1
# Imagem image_0733_left_bottom_png.rf.aacbc1b4feb88aeda9fd43e3f49d5a9a.jpg classificada como 1 com confiança 0.84 e movida para teste_512\C2_03\1
# Imagem image_0734_left_bottom_png.rf.591888aeb74b47034450cfaa87431497.jpg classificada como 1 com confiança 0.84 e movida para teste_512\C2_03\1
# Imagem image_0735_left_bottom_png.rf.1ac9f51e50cd8337a8eb343a64f9a4e6.jpg classificada como 1 com confiança 0.87 e movida para teste_512\C2_03\1
# Imagem image_0736_left_bottom_png.rf.94af830356686754d9500cce7c0739ce.jpg classificada como 1 com confiança 0.88 e movida para teste_512\C2_03\1
# Imagem image_0737_left_bottom_png.rf.3e65de7200025d7c4b35a394553a6785.jpg classificada como 1 com confiança 0.79 e movida para teste_512\C2_03\1
# Imagem image_0738_left_bottom_png.rf.4464f9902c8f54c8b5e962683c8915c5.jpg classificada como 1 com confiança 0.79 e movida para teste_512\C2_03\1
# Imagem image_0739_left_bottom_png.rf.2fd4c86f457f865dfed1a7630a285748.jpg classificada como incerta (confiança 0.55) e movida para teste_512\C2_03\uncertain
# Imagem image_0740_left_bottom_png.rf.dfaadd13f6763d37fb21bafd03634faf.jpg classificada como incerta (confiança 0.56) e movida para teste_512\C2_03\uncertain
# Imagem image_0741_left_bottom_png.rf.3fc85ab54f86d9b3dde91462844dc470.jpg classificada como 2 com confiança 0.83 e movida para teste_512\C2_03\2
# Imagem image_0742_left_bottom_png.rf.1ceaabd3e8acd81f5bc8aa6175d9b70e.jpg classificada como 2 com confiança 0.83 e movida para teste_512\C2_03\2
# Imagem image_0743_left_bottom_png.rf.0c898b167ac58da684323989dbc7953c.jpg classificada como 2 com confiança 0.87 e movida para teste_512\C2_03\2
# Imagem image_0744_left_bottom_png.rf.313ba8008d147ef57cd6c7ec38fd1505.jpg classificada como 2 com confiança 0.87 e movida para teste_512\C2_03\2
# Imagem image_0745_left_bottom_png.rf.c7418f4ff56f8b710c3367daee5b3a27.jpg classificada como 2 com confiança 0.87 e movida para teste_512\C2_03\2
# Imagem image_0746_left_bottom_png.rf.579bc52bf021d17973be4dd802f52637.jpg classificada como 2 com confiança 0.87 e movida para teste_512\C2_03\2
# Imagem image_0747_left_bottom_png.rf.a6004fc21cb40e90f0f97a25e6aa7782.jpg classificada como 2 com confiança 0.94 e movida para teste_512\C2_03\2
# Imagem image_0748_left_bottom_png.rf.d46eee2b7853445bb30c2e0bad510e71.jpg classificada como 2 com confiança 0.94 e movida para teste_512\C2_03\2
# Imagem image_0749_left_bottom_png.rf.f06e065982176bdc648b7fe321372496.jpg classificada como 2 com confiança 0.85 e movida para teste_512\C2_03\2
# Imagem image_0750_left_bottom_png.rf.d8baf7a2f1484e3627b0e5bcb7831a23.jpg classificada como incerta (confiança 0.60) e movida para teste_512\C2_03\uncertain
# Imagem image_0751_left_bottom_png.rf.a099a5db6271f28488fdd73accd7e555.jpg classificada como incerta (confiança 0.60) e movida para teste_512\C2_03\uncertain
# Imagem image_0752_left_bottom_png.rf.b45bc635ede0f22e732e7cc002a763c3.jpg classificada como incerta (confiança 0.62) e movida para teste_512\C2_03\uncertain
# Imagem image_0753_left_bottom_png.rf.55e01ae6acf7d8909323efdc1a5ea00a.jpg classificada como incerta (confiança 0.62) e movida para teste_512\C2_03\uncertain
# Imagem image_0754_left_bottom_png.rf.585449a5d9fd14fb42f5a608610c9604.jpg classificada como 1 com confiança 0.79 e movida para teste_512\C2_03\1
# Imagem image_0755_left_bottom_png.rf.956928fffd1055995fc10bb0d4fddad8.jpg classificada como 1 com confiança 0.79 e movida para teste_512\C2_03\1
# Imagem image_0756_left_bottom_png.rf.b235e1b0e078bf8947938d17923b40b6.jpg classificada como 1 com confiança 0.86 e movida para teste_512\C2_03\1
# Imagem image_0757_left_bottom_png.rf.0aa859bddf63e59bebef87dabf39b9ee.jpg classificada como 1 com confiança 0.87 e movida para teste_512\C2_03\1
# Imagem image_0758_left_bottom_png.rf.7739c13cf8dc7139ba8217a1f7c63cdd.jpg classificada como 1 com confiança 0.86 e movida para teste_512\C2_03\1
# Imagem image_0759_left_bottom_png.rf.bd24df57ebe390b92841a237c46f4a9e.jpg classificada como 1 com confiança 0.85 e movida para teste_512\C2_03\1
# Imagem image_0760_left_bottom_png.rf.b49be6b230598ef0c05731314ff4222b.jpg classificada como 1 com confiança 0.91 e movida para teste_512\C2_03\1
# Imagem image_0761_left_bottom_png.rf.6b55b1d9ab309dffc0389a0e2beb2335.jpg classificada como 1 com confiança 0.91 e movida para teste_512\C2_03\1
# Imagem image_0762_left_bottom_png.rf.1ac86c51dd2b07d7757682e0cfb22d99.jpg classificada como 1 com confiança 0.93 e movida para teste_512\C2_03\1
# Imagem image_0763_left_bottom_png.rf.0bb6e95f846eeb6183af00938bc8b8a5.jpg classificada como 1 com confiança 0.93 e movida para teste_512\C2_03\1
# Imagem image_0764_left_bottom_png.rf.d810681d1b37a0e05ec6c04a1f5f723c.jpg classificada como 1 com confiança 0.94 e movida para teste_512\C2_03\1
# Imagem image_0765_left_bottom_png.rf.633130b1270ffac946a07f1cb752c7c9.jpg classificada como 1 com confiança 0.94 e movida para teste_512\C2_03\1
# Imagem image_0766_left_bottom_png.rf.1f4c784112c63fbdb9bcdcfc0aa04d37.jpg classificada como 1 com confiança 0.94 e movida para teste_512\C2_03\1
# Imagem image_0767_left_bottom_png.rf.25bf20d8c83eb585410c353cad486916.jpg classificada como 1 com confiança 0.94 e movida para teste_512\C2_03\1
# Imagem image_0768_left_bottom_png.rf.496d6747363865a585fc3586c0fd9051.jpg classificada como 1 com confiança 0.95 e movida para teste_512\C2_03\1
# Imagem image_0769_left_bottom_png.rf.33cadb184a6a8fee6a2c202deabee1de.jpg classificada como 1 com confiança 0.95 e movida para teste_512\C2_03\1
# Imagem image_0770_left_bottom_png.rf.b960f5fd2b7b5783da5a4b4d3b876447.jpg classificada como 1 com confiança 0.92 e movida para teste_512\C2_03\1
# Imagem image_0771_left_bottom_png.rf.b9b30064b4bf3b7c0f1fbe5723a59004.jpg classificada como 1 com confiança 0.91 e movida para teste_512\C2_03\1
# Imagem image_0772_left_bottom_png.rf.63d6f3e4cf8c7b61e3b03a5a8570821a.jpg classificada como 1 com confiança 0.77 e movida para teste_512\C2_03\1
# Imagem image_0773_left_bottom_png.rf.32276383ba4b3773627f5535aaabc980.jpg classificada como 1 com confiança 0.77 e movida para teste_512\C2_03\1
# Processando diretório: C2_09
# Imagem image_37927_left_bottom_png.rf.6fa8f45080586d80cbabee193d60a923.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_09\1
# Imagem image_37928_left_bottom_png.rf.0b6379ef02a0a37ccbf32a996908884c.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_09\1
# Imagem image_37929_left_bottom_png.rf.85bc4cfadcdcbee7ba4a447d4bee841e.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_09\1
# Imagem image_37930_left_bottom_png.rf.902105d0e7c116fcec4b3aa80c1d13fc.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_09\1
# Imagem image_37931_left_bottom_png.rf.60adc57a2d24554904a43b287d0e2db3.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_09\1
# Imagem image_37932_left_bottom_png.rf.ea9be65ba53b3040c9bf1bad7c1c4db0.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_09\1
# Imagem image_37933_left_bottom_png.rf.b9e4e04de810814909b1e8b18ccb25c8.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_09\1
# Imagem image_37934_left_bottom_png.rf.fdef531548d361ef5b7996bbc435e92f.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_09\1
# Imagem image_37935_left_bottom_png.rf.9fbe773aa8221b30e528e6425781de6a.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_09\1
# Imagem image_37936_left_bottom_png.rf.f520b8727d845fa8890b9550492a5eb2.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_09\1
# Imagem image_37937_left_bottom_png.rf.b1a99060af68a99017d02b74ccbd819c.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_09\1
# Imagem image_37938_left_bottom_png.rf.ac25b472eea97f388d93a762d269974b.jpg classificada como incerta (confiança 0.54) e movida para teste_512\C2_09\uncertain
# Imagem image_37939_left_bottom_png.rf.2a1b229aa29e7366d0732c24bb3a5e58.jpg classificada como incerta (confiança 0.55) e movida para teste_512\C2_09\uncertain
# Imagem image_37940_left_bottom_png.rf.93ad8935ecf544b216e13f357af2b65f.jpg classificada como incerta (confiança 0.60) e movida para teste_512\C2_09\uncertain
# Imagem image_37941_left_bottom_png.rf.fc4c909dc7a1e6d6d77ce462e9555618.jpg classificada como incerta (confiança 0.60) e movida para teste_512\C2_09\uncertain
# Imagem image_37942_left_bottom_png.rf.95694dabf030f25b2dcb1cd75e3a7adb.jpg classificada como incerta (confiança 0.61) e movida para teste_512\C2_09\uncertain
# Imagem image_37943_left_bottom_png.rf.ad1aa32769a937b2f365b54180dae0de.jpg classificada como incerta (confiança 0.62) e movida para teste_512\C2_09\uncertain
# Imagem image_37944_left_bottom_png.rf.a7f1994e77803d151630155b893129a9.jpg classificada como 2 com confiança 0.78 e movida para teste_512\C2_09\2
# Imagem image_37945_left_bottom_png.rf.06ef576c56fa64496dea271f69dbb733.jpg classificada como 2 com confiança 0.77 e movida para teste_512\C2_09\2
# Imagem image_37946_left_bottom_png.rf.94610b79055a256cb265ba1a4935a823.jpg classificada como 2 com confiança 0.86 e movida para teste_512\C2_09\2
# Imagem image_37947_left_bottom_png.rf.fffcf7069daec4f9412ef7e08e05071d.jpg classificada como 2 com confiança 0.87 e movida para teste_512\C2_09\2
# Imagem image_37948_left_bottom_png.rf.92b9d7bd81e4c9b6b2d242ab03eb4804.jpg classificada como 2 com confiança 0.90 e movida para teste_512\C2_09\2
# Imagem image_37949_left_bottom_png.rf.fd3f3ebe8a1f2261b2ddc7ba07e7df1f.jpg classificada como 2 com confiança 0.90 e movida para teste_512\C2_09\2
# Imagem image_37950_left_bottom_png.rf.85ef7a7364a2834a0b7f3d659fee4d77.jpg classificada como 2 com confiança 0.89 e movida para teste_512\C2_09\2
# Imagem image_37951_left_bottom_png.rf.44e659b8876d01fbef790f863ceba9ff.jpg classificada como 2 com confiança 0.89 e movida para teste_512\C2_09\2
# Imagem image_37952_left_bottom_png.rf.1267191dfea208297607fdfc537fd64d.jpg classificada como 2 com confiança 0.89 e movida para teste_512\C2_09\2
# Imagem image_37953_left_bottom_png.rf.7e0b76268b9a0291400fe36280e6fd49.jpg classificada como 2 com confiança 0.83 e movida para teste_512\C2_09\2
# Imagem image_37954_left_bottom_png.rf.846791ad41d9a04cb863e24a3c4ce595.jpg classificada como 2 com confiança 0.83 e movida para teste_512\C2_09\2
# Imagem image_37955_left_bottom_png.rf.bee9dd1b12a56067e6e00b7416d5f67b.jpg classificada como 2 com confiança 0.84 e movida para teste_512\C2_09\2
# Imagem image_37956_left_bottom_png.rf.dd559d56fa6b6567b390bd0e5e25ecbb.jpg classificada como 2 com confiança 0.85 e movida para teste_512\C2_09\2
# Imagem image_37957_left_bottom_png.rf.804a16fd4bcc2828eece4afefc865714.jpg classificada como 2 com confiança 0.78 e movida para teste_512\C2_09\2
# Imagem image_37958_left_bottom_png.rf.c1aed414995be32199d6196f88d104b3.jpg classificada como 2 com confiança 0.78 e movida para teste_512\C2_09\2
# Imagem image_37959_left_bottom_png.rf.4fbd6c46e1f09725b1bb03937c18b373.jpg classificada como 2 com confiança 0.81 e movida para teste_512\C2_09\2
# Imagem image_37960_left_bottom_png.rf.8bca6c04e1a63e8f7c338c82b40a6685.jpg classificada como 2 com confiança 0.80 e movida para teste_512\C2_09\2
# Imagem image_37961_left_bottom_png.rf.56c1652df8cd3b6aa9f5880005aae2f6.jpg classificada como incerta (confiança 0.57) e movida para teste_512\C2_09\uncertain
# Imagem image_37962_left_bottom_png.rf.0db62c05833ce32862499ff50c41f0d0.jpg classificada como incerta (confiança 0.54) e movida para teste_512\C2_09\uncertain
# Imagem image_37963_left_bottom_png.rf.c290536222b35d92ca7c05a4a3a5fdf0.jpg classificada como 1 com confiança 0.97 e movida para teste_512\C2_09\1
# ...
# Imagem image_0547_left_bottom_png.rf.0bec2a91c5accc5544e391b4a33cd88c.jpg classificada como 2 com confiança 0.93 e movida para teste_512\C2_61\2
# Imagem image_0548_left_bottom_png.rf.ce17a6e6968db78adcebf8248022607f.jpg classificada como 2 com confiança 0.93 e movida para teste_512\C2_61\2
# Imagem image_0549_left_bottom_png.rf.5f5003f3d50454e57c4c50ab12412b5b.jpg classificada como 2 com confiança 0.94 e movida para teste_512\C2_61\2
# Imagem image_0550_left_bottom_png.rf.a01098b089cf9db716f4a71dc366fd1f.jpg classificada como 2 com confiança 0.92 e movida para teste_512\C2_61\2
# Imagem image_0551_left_bottom_png.rf.8be65424301f2dbc9065ff27ef89ee2c.jpg classificada como 2 com confiança 0.91 e movida para teste_512\C2_61\2
# Imagem image_0552_left_bottom_png.rf.fc3c3270b3cce899abf8705a92a7e8f7.jpg classificada como 2 com confiança 0.90 e movida para teste_512\C2_61\2
# Imagem image_0553_left_bottom_png.rf.9309e10e916897447e05161d744c5b62.jpg classificada como 2 com confiança 0.90 e movida para teste_512\C2_61\2
# Imagem image_0554_left_bottom_png.rf.0ed9b000a5452efac80397f690610435.jpg classificada como 2 com confiança 0.92 e movida para teste_512\C2_61\2
# Imagem image_0555_left_bottom_png.rf.6dbab3e2c94541583f1f9c4bd387e5f7.jpg classificada como 2 com confiança 0.92 e movida para teste_512\C2_61\2
# Imagem image_0556_left_bottom_png.rf.d989862de8b1d346917fec5e618b1539.jpg classificada como incerta (confiança 0.50) e movida para teste_512\C2_61\uncertain
# Imagem image_0557_left_bottom_png.rf.f23b16ff8e22b2d51b1d2f272b3572ee.jpg classificada como incerta (confiança 0.50) e movida para teste_512\C2_61\uncertain
# Imagem image_0558_left_bottom_png.rf.5356f3c56cc7688e3c247da6751e102a.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_61\1
# Imagem image_0559_left_bottom_png.rf.0164863ff6eb707e3910b9504d6ee516.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_61\1
# Imagem image_0560_left_bottom_png.rf.09a9d385b0f62373c8b8fe8d95e5cc85.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_61\1
# Imagem image_0561_left_bottom_png.rf.ab4055f83a195989315edbece8548f08.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_61\1
# Imagem image_0562_left_bottom_png.rf.dd7c75c068157aa2add16e17a89990c2.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_61\1
# Imagem image_0563_left_bottom_png.rf.526920cfdb575a16a06a5115b783ec80.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_61\1
# Imagem image_0564_left_bottom_png.rf.bff3fb4678d1d18fe42cb3530b6a8d5f.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_61\1
# Imagem image_0565_left_bottom_png.rf.503a68bf644f33912b8406a6feb34903.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_61\1
# Imagem image_0566_left_bottom_png.rf.74c9920a43373a84090e1345d87dd0fe.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_61\1
# Imagem image_0567_left_bottom_png.rf.e2b09f81b50324dc204066a3aa3d1b1b.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_61\1
# Imagem image_0568_left_bottom_png.rf.7fffb491e2e5e4ba444478eea109f43c.jpg classificada como 1 com confiança 0.97 e movida para teste_512\C2_61\1
# Imagem image_0569_left_bottom_png.rf.fd0e17ed7662f3162ebe8400841c2d01.jpg classificada como 1 com confiança 0.97 e movida para teste_512\C2_61\1
# Imagem image_0570_left_bottom_png.rf.621c28565d11bffbdf9862ee90034d48.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_61\1
# Imagem image_0571_left_bottom_png.rf.fbe192e2be6bf1ae8466023bbbccf4eb.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0572_left_bottom_png.rf.a11667363d8642f6c0a3bc57ecf4b6fd.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0573_left_bottom_png.rf.cb8b882efbb77a980ed919c9009aad67.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0574_left_bottom_png.rf.211ca578096c01ce736beb115248008c.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0575_left_bottom_png.rf.3736afc148c36097679f227616921107.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0576_left_bottom_png.rf.2fe21a3bc9229ca3cc46541027efcddd.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0577_left_bottom_png.rf.3f78c551e4972f3b3338cbe066716024.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0578_left_bottom_png.rf.0e9820223839a3d996e75f3907307417.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0579_left_bottom_png.rf.e6e0c3aaa97adfc3938af26fb3873fc3.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0580_left_bottom_png.rf.75ae3c5672bc511105c14a2b17c611d4.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0581_left_bottom_png.rf.61d1123a3f72518a6f209259e0694c05.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0582_left_bottom_png.rf.885c35015d429a9d9d7c79b1fc58a283.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0583_left_bottom_png.rf.a93c3ec523c770be2dd399b1ab2d43f6.jpg classificada como 0 com confiança 0.93 e movida para teste_512\C2_61\0
# Imagem image_0584_left_bottom_png.rf.7ae7bbe1b0b8ff9e420dded9215574a7.jpg classificada como 0 com confiança 0.93 e movida para teste_512\C2_61\0
# Imagem image_0585_left_bottom_png.rf.7d7fcc64882b66e962acca5bf2f40c59.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0586_left_bottom_png.rf.774efdf740db2e95bfaadd6c12397ac3.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0587_left_bottom_png.rf.6e70ea36302e40e297ed3752575f3359.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0588_left_bottom_png.rf.1258237ba22e32824219004a170ecf71.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0589_left_bottom_png.rf.11985c566faf65131114f4aa977b3350.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0590_left_bottom_png.rf.beda5ca69f1f78155edc55db47598da6.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Imagem image_0591_left_bottom_png.rf.99698935399dc8c2ca01e30344bb353a.jpg classificada como 0 com confiança 0.94 e movida para teste_512\C2_61\0
# Processando diretório: C2_64
# Imagem image_1184_left_bottom_png.rf.ac7bdcbf42874ad9de5cbc2fe4c6e5d8.jpg classificada como 1 com confiança 0.94 e movida para teste_512\C2_64\1
# Imagem image_1185_left_bottom_png.rf.e155cd526c980ae0fbad287050b65ee3.jpg classificada como 1 com confiança 0.95 e movida para teste_512\C2_64\1
# Imagem image_1186_left_bottom_png.rf.a1e0eb1654971d2f3e3fa63855312819.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1187_left_bottom_png.rf.ab155b55ba4ea0aa4869260acfee65cd.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1188_left_bottom_png.rf.15f764d008412f2975f2ce404017dbfb.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1189_left_bottom_png.rf.afc79548763c5917ae61443352709146.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1190_left_bottom_png.rf.59dda8cb21d7b4b5525b135f2142aa04.jpg classificada como incerta (confiança 0.65) e movida para teste_512\C2_64\uncertain
# Imagem image_1191_left_bottom_png.rf.fbcde1dedb4b4c4796e556bedda27255.jpg classificada como incerta (confiança 0.65) e movida para teste_512\C2_64\uncertain
# Imagem image_1192_left_bottom_png.rf.58bb35aceb5d36b01cd3efdc6f22d525.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1193_left_bottom_png.rf.9a7c712496efbeadf38fa4d46c9a7df5.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1194_left_bottom_png.rf.de05e2fc682a85662231c0ed9cece0f8.jpg classificada como 1 com confiança 0.93 e movida para teste_512\C2_64\1
# Imagem image_1195_left_bottom_png.rf.0852b1cf39a664121750dc4d617c7c0f.jpg classificada como 1 com confiança 0.95 e movida para teste_512\C2_64\1
# Imagem image_1196_left_bottom_png.rf.46ce138966087e9cf64ab0c238874703.jpg classificada como incerta (confiança 0.69) e movida para teste_512\C2_64\uncertain
# Imagem image_1197_left_bottom_png.rf.d0b9fe1af448e334373d86a095528bdf.jpg classificada como incerta (confiança 0.67) e movida para teste_512\C2_64\uncertain
# Imagem image_1198_left_bottom_png.rf.704930e6f824196a04831906a8c0b402.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1199_left_bottom_png.rf.b7cbd037cbff3f1b1d3ca12dd6688a3c.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1200_left_bottom_png.rf.fd1350d73c7fc9e5d82b5bcea5d07355.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1201_left_bottom_png.rf.c7629d887add311b9a00ced4c2d8cdcc.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1202_left_bottom_png.rf.458731d6824c2550850921fca5b5a7f3.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1203_left_bottom_png.rf.72e3728007d8eab6f5d0883b85371103.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1204_left_bottom_png.rf.49f1438d1220eb85774c75424c21025f.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1205_left_bottom_png.rf.e3df7fe5a087f859b645e44dc36f8e84.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1206_left_bottom_png.rf.baba9ea0b95160c44ac89572f3f57681.jpg classificada como 1 com confiança 1.00 e movida para teste_512\C2_64\1
# Imagem image_1207_left_bottom_png.rf.39f6d80c3d1288e3c128797b636ada44.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1208_left_bottom_png.rf.9869c9e4455d49205e506959e1d08997.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1209_left_bottom_png.rf.1251def117b407f7207e212357218fc7.jpg classificada como 1 com confiança 0.78 e movida para teste_512\C2_64\1
# Imagem image_1210_left_bottom_png.rf.ecec25c5b52c2a5a4c863d61a354649a.jpg classificada como 1 com confiança 0.77 e movida para teste_512\C2_64\1
# Imagem image_1211_left_bottom_png.rf.cd4e10845034c8c667eb437921253983.jpg classificada como 2 com confiança 0.88 e movida para teste_512\C2_64\2
# Imagem image_1212_left_bottom_png.rf.77a655ffd7925f31e087fcc2d4263a3f.jpg classificada como 2 com confiança 0.88 e movida para teste_512\C2_64\2
# Imagem image_1213_left_bottom_png.rf.17241f2616ab069deccfea9b44535165.jpg classificada como 2 com confiança 0.93 e movida para teste_512\C2_64\2
# Imagem image_1214_left_bottom_png.rf.46fa0913fe3ac29bd5f30fa915049f1a.jpg classificada como 2 com confiança 0.93 e movida para teste_512\C2_64\2
# Imagem image_1215_left_bottom_png.rf.04a66cf20a34a681065d27f30481692a.jpg classificada como 2 com confiança 0.93 e movida para teste_512\C2_64\2
# Imagem image_1216_left_bottom_png.rf.42888303e12fe8eb1c188f31bc88233f.jpg classificada como 2 com confiança 0.92 e movida para teste_512\C2_64\2
# Imagem image_1217_left_bottom_png.rf.e55daded1a9fd2e6e74304691f87a076.jpg classificada como incerta (confiança 0.59) e movida para teste_512\C2_64\uncertain
# Imagem image_1218_left_bottom_png.rf.2fc572bbe15261e387b169714073ca22.jpg classificada como incerta (confiança 0.59) e movida para teste_512\C2_64\uncertain
# Imagem image_1219_left_bottom_png.rf.6903dc581e1ba106a1712319c2af50b9.jpg classificada como 1 com confiança 0.95 e movida para teste_512\C2_64\1
# Imagem image_1220_left_bottom_png.rf.803fccca41401c0f904746dd100bce75.jpg classificada como 1 com confiança 0.95 e movida para teste_512\C2_64\1
# Imagem image_1221_left_bottom_png.rf.1b444b328dd3efc9a7ff95f343999153.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1222_left_bottom_png.rf.0f1ff86f72ccab93b4a9725fcea23714.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1223_left_bottom_png.rf.9d25190d7314fbce19e3d6846969ef62.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1224_left_bottom_png.rf.632efbc8879bbd5dbdfed060fe5da859.jpg classificada como 1 com confiança 0.99 e movida para teste_512\C2_64\1
# Imagem image_1225_left_bottom_png.rf.e0d835ff2db863ec6c1d6a43ba0822ed.jpg classificada como 1 com confiança 0.96 e movida para teste_512\C2_64\1
# Imagem image_1226_left_bottom_png.rf.3e3d661c5d6117af962ad0a735a5c70b.jpg classificada como 1 com confiança 0.96 e movida para teste_512\C2_64\1
# Imagem image_1227_left_bottom_png.rf.f996fbb5e2ce028634f95fa6714b272b.jpg classificada como 1 com confiança 0.96 e movida para teste_512\C2_64\1
# Imagem image_1228_left_bottom_png.rf.73f4ee35b4d2ee52dd1b9cb1cae5a0b1.jpg classificada como 1 com confiança 0.95 e movida para teste_512\C2_64\1
# Imagem image_1229_left_bottom_png.rf.b6a349e6171190f3f4a30cb7d1898ae5.jpg classificada como 1 com confiança 0.97 e movida para teste_512\C2_64\1
# Imagem image_1230_left_bottom_png.rf.4cfaf6be9436388963b391cee78923cf.jpg classificada como 1 com confiança 0.92 e movida para teste_512\C2_64\1
# Imagem image_1231_left_bottom_png.rf.a08bbdf66c5f57a88755257d45c22534.jpg classificada como 1 com confiança 0.91 e movida para teste_512\C2_64\1
# Imagem image_1232_left_bottom_png.rf.4df0ee849adb13864b87d89fe8295b20.jpg classificada como 1 com confiança 0.94 e movida para teste_512\C2_64\1
# Imagem image_1233_left_bottom_png.rf.77fa5703f10fb5468a0c704b4569ca0d.jpg classificada como 1 com confiança 0.94 e movida para teste_512\C2_64\1
# Imagem image_1234_left_bottom_png.rf.57089392f025b4256731251603637633.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_64\1
# Imagem image_1235_left_bottom_png.rf.8a9e840f390fa813f9d6ad13c11d32eb.jpg classificada como 1 com confiança 0.98 e movida para teste_512\C2_64\1
# Imagem image_1236_left_bottom_png.rf.e83524a3fb056d0b9fa7275815e87c74.jpg classificada como 0 com confiança 0.88 e movida para teste_512\C2_64\0
# Imagem image_1237_left_bottom_png.rf.0d732473cf1ac8eccf64d999ccbdcd06.jpg classificada como 0 com confiança 0.88 e movida para teste_512\C2_64\0
# Imagem image_1238_left_bottom_png.rf.459ec87f3e76e3e692cb30571b3e741b.jpg classificada como 0 com confiança 0.90 e movida para teste_512\C2_64\0
# Imagem image_1239_left_bottom_png.rf.fd2e8a953cd636ded49d6aa4edfddb72.jpg classificada como 0 com confiança 0.90 e movida para teste_512\C2_64\0
# Imagem image_1240_left_bottom_png.rf.255eddf3ff31dfe7887bdb8945d3be56.jpg classificada como 0 com confiança 0.90 e movida para teste_512\C2_64\0
# Imagem image_1241_left_bottom_png.rf.fd1efaaddf2b5b7f0aca22b15075c0d6.jpg classificada como 0 com confiança 0.90 e movida para teste_512\C2_64\0
# Imagem image_1242_left_bottom_png.rf.d7da3a084ef943c42b2a2314c9185cb7.jpg classificada como 0 com confiança 0.91 e movida para teste_512\C2_64\0
# Imagem image_1243_left_bottom_png.rf.c708685297529875f3eb09f5b009d89a.jpg classificada como 0 com confiança 0.91 e movida para teste_512\C2_64\0
# Imagem image_1244_left_bottom_png.rf.7d24e9a2cd017af03da2da2e92d3f6a7.jpg classificada como 0 com confiança 0.91 e movida para teste_512\C2_64\0
# Imagem image_1245_left_bottom_png.rf.329333a075254b194ea3d65957dfa6be.jpg classificada como 0 com confiança 0.90 e movida para teste_512\C2_64\0
# Imagem image_1246_left_bottom_png.rf.fcd49f8b3da2ec9ea56789be2f1db29e.jpg classificada como 0 com confiança 0.92 e movida para teste_512\C2_64\0
# Imagem image_1247_left_bottom_png.rf.04f05f85a56a6ecf88dcdef94e088c9d.jpg classificada como 0 com confiança 0.92 e movida para teste_512\C2_64\0
