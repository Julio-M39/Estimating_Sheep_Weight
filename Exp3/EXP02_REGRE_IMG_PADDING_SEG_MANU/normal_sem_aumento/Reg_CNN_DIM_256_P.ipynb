# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import *
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from scipy.stats import pearsonr
from sklearn.model_selection import StratifiedKFold

# Importar modelos e suas respectivas funções preprocess_input
from tensorflow.keras.applications.xception import Xception, preprocess_input as preprocess_xception
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input as preprocess_vgg16
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input as preprocess_vgg19
from tensorflow.keras.applications.resnet import ResNet50, ResNet101, ResNet152, preprocess_input as preprocess_resnet
from tensorflow.keras.applications.resnet_v2 import ResNet50V2, ResNet101V2, ResNet152V2, preprocess_input as preprocess_resnet_v2
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input as preprocess_inception_v3
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input as preprocess_inception_resnet_v2
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input as preprocess_mobilenet
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input as preprocess_mobilenet_v2
from tensorflow.keras.applications.densenet import DenseNet121, DenseNet169, DenseNet201, preprocess_input as preprocess_densenet
from tensorflow.keras.applications.nasnet import NASNetMobile, NASNetLarge, preprocess_input as preprocess_nasnet
from tensorflow.keras.applications.efficientnet import EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetB4, EfficientNetB5, EfficientNetB6, EfficientNetB7, preprocess_input as preprocess_efficientnet
# Add EfficientNetV2 imports if available in your TensorFlow version
# from tensorflow.keras.applications.efficientnet_v2 import ...

# Definição do tamanho de entrada para cada modelo de CNN
model_input_sizes = {
    'Xception': (256, 256), #1
    'VGG16': (256, 256), #2
    'VGG19': (256, 256), #3 
    'ResNet50': (256, 256), #4 
    'ResNet50V2': (256, 256), #5 
    'ResNet101': (256, 256), #6 
    'ResNet101V2': (256, 256), #7 
    'ResNet152': (256, 256), #8
    'ResNet152V2': (256, 256), #9
    'InceptionV3': (256, 256), #10 
    'InceptionResNetV2': (256, 256), #11
    'MobileNet': (256, 256), #12 
    'MobileNetV2': (256, 256), #13
    'DenseNet121': (256, 256), #14
    'DenseNet169': (256, 256), #15
    'DenseNet201': (256, 256), #16 
    #'NASNetMobile': (224, 224), #17
    #'NASNetLarge': (331, 331), #18 
    'EfficientNetB0': (256, 256), #19
    'EfficientNetB1': (256, 256), #20
    'EfficientNetB2': (256, 256), #21
    'EfficientNetB3': (256, 256), #22
    'EfficientNetB4': (256, 256), #23
    'EfficientNetB5': (256, 256), #24
    'EfficientNetB6': (256, 256), #25
    'EfficientNetB7': (256, 256), #26
    # Add sizes for EfficientNetV2 models if needed
}

model_info = {
    'Xception': (Xception, preprocess_xception),
    'VGG16': (VGG16, preprocess_vgg16),
    'VGG19': (VGG19, preprocess_vgg19), #3
    'ResNet50': (ResNet50, preprocess_resnet), #4
    'ResNet50V2': (ResNet50V2, preprocess_resnet_v2), #5
    'ResNet101': (ResNet101, preprocess_resnet), #6
    'ResNet101V2': (ResNet101V2, preprocess_resnet_v2), #7
    'ResNet152': (ResNet152, preprocess_resnet), #8
    'ResNet152V2': (ResNet152V2, preprocess_resnet_v2), #9
    'InceptionV3': (InceptionV3, preprocess_inception_v3), #10
    'InceptionResNetV2': (InceptionResNetV2, preprocess_inception_resnet_v2), #11
    'MobileNet': (MobileNet, preprocess_mobilenet), #12
    'MobileNetV2': (MobileNetV2, preprocess_mobilenet_v2), #13
    'DenseNet121': (DenseNet121, preprocess_densenet), #14
    'DenseNet169': (DenseNet169, preprocess_densenet), #15
    'DenseNet201': (DenseNet201, preprocess_densenet), #16
    #'NASNetMobile': (NASNetMobile, preprocess_nasnet), #17
    #'NASNetLarge': (NASNetLarge, preprocess_nasnet), #18
    'EfficientNetB0': (EfficientNetB0, preprocess_efficientnet), #19
    'EfficientNetB1': (EfficientNetB1, preprocess_efficientnet), #20
    'EfficientNetB2': (EfficientNetB2, preprocess_efficientnet), #21
    'EfficientNetB3': (EfficientNetB3, preprocess_efficientnet), #22
    'EfficientNetB4': (EfficientNetB4, preprocess_efficientnet), #23
    'EfficientNetB5': (EfficientNetB5, preprocess_efficientnet), #24
    'EfficientNetB6': (EfficientNetB6, preprocess_efficientnet), #25
    'EfficientNetB7': (EfficientNetB7, preprocess_efficientnet), #26
}

# Função para preprocessar imagem
def preprocess_image(img_path, model_name):
    target_size = model_input_sizes[model_name]
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    preprocess_input_func = model_info[model_name][1]
    return preprocess_input_func(img_array_expanded_dims)

# Inicializar modelo
def init_model(model_name):
    model_class = model_info[model_name][0]
    model = model_class(weights='imagenet', include_top=False, pooling='avg')
    return model

# Extrair características
def extract_features(model, img_path, model_name):
    preprocessed_img = preprocess_image(img_path, model_name)
    features = model.predict(preprocessed_img)
    return features.flatten()

# Função para executar K-Fold de forma estratificada
def run_stratified_kfold_regressions(X, y, group_labels, model_cnn):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    models = [
        ('Linear Regression', LinearRegression()),
        ('Random Forest', RandomForestRegressor(random_state=42)),
        ('SVR', SVR()),
        ('Lasso', Lasso(random_state=42)),
        ('ElasticNet', ElasticNet(random_state=42)),
        ('Ridge', Ridge(random_state=42))
    ]
    
    all_results = []
    
    for name, model in models:
        mse_scores, rmse_scores, mae_scores, r2_scores, r_scores = [], [], [], [], []
        print(f"\nRegressão com {name}:")
        fold_number = 1
        for train_index, test_index in skf.split(X, group_labels):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            
            # Verificar a distribuição de C1 e C2 em cada fold
            train_labels = group_labels[train_index]
            test_labels = group_labels[test_index]
            print(f"Fold {fold_number}:")
            print(f" - Treino: {sum(train_labels == 'C1')} C1, {sum(train_labels == 'C2')} C2")
            print(f" - Teste: {sum(test_labels == 'C1')} C1, {sum(test_labels == 'C2')} C2")
            
            fold_number += 1

            # Treinar o modelo e fazer previsões
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            mse = mean_squared_error(y_test, y_pred)
            rmse = np.sqrt(mse)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)
            r = pearsonr(y_test, y_pred)[0] if np.var(y_pred) > 0 else 0
            
            mse_scores.append(mse)
            rmse_scores.append(rmse)
            mae_scores.append(mae)
            r2_scores.append(r2)
            r_scores.append(r)

            for real, pred in zip(y_test, y_pred):
                print(f"Peso Real: {real}, Peso Predito: {pred:.2f}")

            print(f"Fold: {len(mse_scores)}, MSE: {mse:.2f}, RMSE: {rmse:.2f}, MAE: {mae:.2f}, R2: {r2:.2f}, R: {r:.2f}")

        print(f"\nMédia dos resultados para {name}:")
        print(f"MSE: {np.mean(mse_scores):.2f} ± {np.std(mse_scores):.2f}")
        print(f"RMSE: {np.mean(rmse_scores):.2f} ± {np.std(rmse_scores):.2f}")
        print(f"MAE: {np.mean(mae_scores):.2f} ± {np.std(mae_scores):.2f}")
        print(f"R2: {np.mean(r2_scores):.2f} ± {np.std(r2_scores):.2f}")
        print(f"R: {np.mean(r_scores):.2f} ± {np.std(r_scores):.2f}")

        all_results.append({
            'REGRESSAO': name,
            'MSE': f"{np.mean(mse_scores):.2f} ± {np.std(mse_scores):.2f}",
            'RMSE': f"{np.mean(rmse_scores):.2f} ± {np.std(rmse_scores):.2f}",
            'MAE': f"{np.mean(mae_scores):.2f} ± {np.std(mae_scores):.2f}",
            'R2': f"{np.mean(r2_scores):.2f} ± {np.std(r2_scores):.2f}",
            'R': f"{np.mean(r_scores):.2f} ± {np.std(r_scores):.2f}",
            'CNN': model_cnn
        })
        
    return all_results

# Carregar dados
df = pd.read_csv('all_animal_images.csv')

# Adicionar uma nova coluna que identifica se o animal é do grupo C1 ou C2
df['Group'] = df['ID Animal'].apply(lambda x: 'C1' if 'C1_' in x else 'C2')

# Processar imagens e características para cada modelo
final_results = []
for model_name in model_info.keys():
    print(f"\nIniciando processamento com modelo: {model_name}")
    model = init_model(model_name)
    feature_dict = {}
    
    for index, row in df.iterrows():
        animal_id = row['ID Animal']
        img_path = row['Path']
        features = extract_features(model, img_path, model_name)
        if animal_id not in feature_dict:
            feature_dict[animal_id] = []
        feature_dict[animal_id].append(features)
        print(f"Características extraídas para ID {animal_id} da imagem {img_path}")

    for animal_id, feats in feature_dict.items():
        aggregate_features = np.mean(feats, axis=0)
        feature_dict[animal_id] = aggregate_features
        print(f"Vetor de características agregado para ID {animal_id}: {aggregate_features.shape}")

    feature_df = pd.DataFrame.from_dict(feature_dict, orient='index')
    weights = df[['ID Animal', 'Peso', 'Group']].drop_duplicates().set_index('ID Animal')
    feature_df = feature_df.join(weights)

    X = feature_df.iloc[:, :-2].values
    y = feature_df['Peso'].values
    group_labels = feature_df['Group'].values

    results = run_stratified_kfold_regressions(X, y, group_labels, model_name)
    final_results.extend(results)

# Criar DataFrame e salvar em Excel
results_df = pd.DataFrame(final_results)
results_df.to_excel('regression_results_256_padding_seg_alci_will_stratified.xlsx', index=False)
print("Resultados salvos em 'regression_results_256_padding_seg_alci_will_stratified.xlsx'.")
# Out:
# Iniciando processamento com modelo: Xception
# 1/1 [==============================] - 2s 2s/step
# Características extraídas para ID C2_01 da imagem base_alci\C2_01\padding_seg\image_3849_left_bottom_png.rf.db8d9ec2337f0bf680737d579f2facdc.jpg
# 1/1 [==============================] - 0s 28ms/step
# Características extraídas para ID C2_01 da imagem base_alci\C2_01\padding_seg\image_3850_left_bottom_png.rf.56fb2090cc2f716ff959d968adee9652.jpg
# 1/1 [==============================] - 0s 24ms/step
# Características extraídas para ID C2
ms/step
# Características extraídas para ID C2_04 da imagem base_alci\C2_04\padding_seg\image_7428_inferior_esquerda_png.rf.428aaf68943495559846576184bdb720.jpg
# 1/1 [==============================] - 0s 21ms/step
# Características extraídas para ID C2_04 da imagem base_alci\C2_04\padding_seg\image_7429_inferior_esquerda_png.rf.5bc42673995342d401a7ec93fd844e14.jpg
# 1/1 [==============================] - 0s 21ms/step
# ...
#  - Treino: 33 C1, 46 C2
#  - Teste: 9 C1, 11 C2
# Peso Real: 33.2, Peso Predito: 29.25
# Peso Real: 29.15, Peso Predito: 26.03
# Peso Real: 38.25, Peso Predito: 28.30
# Peso Real: 27.8, Peso Predito: 26.38
# Peso Real: 30.4, Peso Predito: 26.38
# Peso Real: 35.2, Peso Predito: 30.67
# Peso Real: 40.45, Peso Predito: 28.52
# Peso Real: 35.75, Peso Predito: 31.36
# Peso Real: 35.3, Peso Predito: 29.02
# Peso Real: 29.9, Peso Predito: 28.28
# Peso Real: 11.45, Peso Predito: 25.34
# Peso Real: 31.4, Peso Predito: 28.27
# Peso Real: 27.0, Peso Predito: 28.00
# Peso Real: 7.5, Peso Predito: 24.72
# Peso Real: 31.9, Peso Predito: 26.94
# Peso Real: 17.5, Peso Predito: 26.62
# Peso Real: 35.2, Peso Predito: 27.37
# Peso Real: 31.7, Peso Predito: 26.02
# Peso Real: 12.9, Peso Predito: 26.59
# Peso Real: 34.4, Peso Predito: 27.35
# Fold: 3, MSE: 65.27, RMSE: 8.08, MAE: 6.74, R2: 0.19, R: 0.67
# Fold 4:
#  - Treino: 33 C1, 46 C2
#  - Teste: 9 C1, 11 C2
# Peso Real: 12.3, Peso Predito: 26.97
# Peso Real: 7.45, Peso Predito: 27.38
# Peso Real: 11.95, Peso Predito: 27.69
# Peso Real: 41.65, Peso Predito: 31.47
# Peso Real: 39.55, Peso Predito: 30.00
# Peso Real: 18.0, Peso Predito: 28.21
# Peso Real: 38.75, Peso Predito: 31.04
# Peso Real: 9.1, Peso Predito: 26.77
# Peso Real: 11.9, Peso Predito: 27.67
# Peso Real: 30.65, Peso Predito: 30.99
# Peso Real: 24.8, Peso Predito: 31.05
# Peso Real: 30.7, Peso Predito: 29.90
# Peso Real: 22.55, Peso Predito: 28.84
# Peso Real: 22.55, Peso Predito: 29.83
# Peso Real: 29.8, Peso Predito: 29.45
# Peso Real: 35.3, Peso Predito: 30.16
# Peso Real: 33.6, Peso Predito: 29.52
# Peso Real: 16.7, Peso Predito: 27.88
# Peso Real: 20.05, Peso Predito: 28.81
# Peso Real: 13.9, Peso Predito: 27.60
# Fold: 4, MSE: 117.22, RMSE: 10.83, MAE: 9.28, R2: -0.04, R: 0.89
# Fold 5:
#  - Treino: 34 C1, 46 C2
#  - Teste: 8 C1, 11 C2
# Peso Real: 7.1, Peso Predito: 26.13
# Peso Real: 12.55, Peso Predito: 26.66
# Peso Real: 30.55, Peso Predito: 31.28
# Peso Real: 29.7, Peso Predito: 29.91
# Peso Real: 41.4, Peso Predito: 30.53
# Peso Real: 14.3, Peso Predito: 28.17
# Peso Real: 27.5, Peso Predito: 31.28
# Peso Real: 14.9, Peso Predito: 27.54
# Peso Real: 28.55, Peso Predito: 30.24
# Peso Real: 32.75, Peso Predito: 32.25
# Peso Real: 31.0, Peso Predito: 31.94
# Peso Real: 35.9, Peso Predito: 30.31
# Peso Real: 6.8, Peso Predito: 27.72
# Peso Real: 33.25, Peso Predito: 29.54
# Peso Real: 27.55, Peso Predito: 29.16
# Peso Real: 30.4, Peso Predito: 28.70
# Peso Real: 23.25, Peso Predito: 29.18
# Peso Real: 22.25, Peso Predito: 29.44
# Peso Real: 13.65, Peso Predito: 28.74
# Fold: 5, MSE: 97.53, RMSE: 9.88, MAE: 7.37, R2: -0.02, R: 0.80
#
# Média dos resultados para SVR:
# MSE: 102.73 ± 31.45
# RMSE: 10.02 ± 1.53
# MAE: 8.13 ± 1.13
# R2: 0.07 ± 0.09
# R: 0.70 ± 0.16
#
# Regressão com Lasso:
# Fold 1:
#  - Treino: 34 C1, 45 C2
#  - Teste: 8 C1, 12 C2
# Peso Real: 29.85, Peso Predito: 26.96
# Peso Real: 40.25, Peso Predito: 28.03
# Peso Real: 5.6, Peso Predito: 20.51
# Peso Real: 11.85, Peso Predito: 21.54
# Peso Real: 35.0, Peso Predito: 27.64
# Peso Real: 17.2, Peso Predito: 23.83
# Peso Real: 11.8, Peso Predito: 26.31
# Peso Real: 35.65, Peso Predito: 26.57
# Peso Real: 42.65, Peso Predito: 28.91
# Peso Real: 31.6, Peso Predito: 24.44
# Peso Real: 15.95, Peso Predito: 27.15
# Peso Real: 33.5, Peso Predito: 29.46
# Peso Real: 9.45, Peso Predito: 19.44
# Peso Real: 33.0, Peso Predito: 23.66
# Peso Real: 32.6, Peso Predito: 23.84
# Peso Real: 27.3, Peso Predito: 26.96
# Peso Real: 31.0, Peso Predito: 24.82
# Peso Real: 13.2, Peso Predito: 21.09
# Peso Real: 25.2, Peso Predito: 23.68
# Peso Real: 62.1, Peso Predito: 24.90
# Fold: 1, MSE: 149.85, RMSE: 12.24, MAE: 9.73, R2: 0.16, R: 0.57
# Fold 2:
#  - Treino: 34 C1, 45 C2
#  - Teste: 8 C1, 12 C2
# Peso Real: 17.4, Peso Predito: 28.25
# Peso Real: 21.2, Peso Predito: 27.65
# Peso Real: 30.1, Peso Predito: 31.12
# Peso Real: 20.0, Peso Predito: 26.02
# Peso Real: 30.65, Peso Predito: 28.30
# Peso Real: 21.65, Peso Predito: 28.61
# Peso Real: 34.65, Peso Predito: 29.85
# Peso Real: 32.2, Peso Predito: 29.91
# Peso Real: 36.65, Peso Predito: 28.16
# Peso Real: 16.55, Peso Predito: 25.95
# Peso Real: 33.8, Peso Predito: 28.86
# Peso Real: 15.4, Peso Predito: 26.24
# Peso Real: 41.0, Peso Predito: 29.60
# Peso Real: 11.0, Peso Predito: 20.03
# Peso Real: 36.0, Peso Predito: 27.69
# Peso Real: 33.6, Peso Predito: 22.80
# Peso Real: 34.8, Peso Predito: 26.02
# Peso Real: 44.2, Peso Predito: 28.17
# Peso Real: 15.8, Peso Predito: 25.71
# Peso Real: 25.5, Peso Predito: 20.35
# Fold: 2, MSE: 71.86, RMSE: 8.48, MAE: 7.69, R2: 0.18, R: 0.45
# Fold 3:
#  - Treino: 33 C1, 46 C2
#  - Teste: 9 C1, 11 C2
# Peso Real: 33.2, Peso Predito: 29.03
# Peso Real: 29.15, Peso Predito: 26.80
# Peso Real: 38.25, Peso Predito: 26.21
# Peso Real: 27.8, Peso Predito: 26.42
# Peso Real: 30.4, Peso Predito: 25.36
# Peso Real: 35.2, Peso Predito: 29.67
# Peso Real: 40.45, Peso Predito: 25.15
# Peso Real: 35.75, Peso Predito: 29.46
# Peso Real: 35.3, Peso Predito: 27.22
# Peso Real: 29.9, Peso Predito: 26.03
# Peso Real: 11.45, Peso Predito: 24.70
# Peso Real: 31.4, Peso Predito: 27.88
# Peso Real: 27.0, Peso Predito: 25.62
# Peso Real: 7.5, Peso Predito: 18.18
# Peso Real: 31.9, Peso Predito: 23.80
# Peso Real: 17.5, Peso Predito: 25.21
# Peso Real: 35.2, Peso Predito: 26.38
# Peso Real: 31.7, Peso Predito: 25.36
# Peso Real: 12.9, Peso Predito: 24.41
# Peso Real: 34.4, Peso Predito: 25.45
# Fold: 3, MSE: 66.98, RMSE: 8.18, MAE: 7.22, R2: 0.17, R: 0.65
# Fold 4:
#  - Treino: 33 C1, 46 C2
#  - Teste: 9 C1, 11 C2
# Peso Real: 12.3, Peso Predito: 21.91
# Peso Real: 7.45, Peso Predito: 24.76
# Peso Real: 11.95, Peso Predito: 26.77
# Peso Real: 41.65, Peso Predito: 29.95
# Peso Real: 39.55, Peso Predito: 28.74
# Peso Real: 18.0, Peso Predito: 27.12
# Peso Real: 38.75, Peso Predito: 29.82
# Peso Real: 9.1, Peso Predito: 24.65
# Peso Real: 11.9, Peso Predito: 26.27
# Peso Real: 30.65, Peso Predito: 30.24
# Peso Real: 24.8, Peso Predito: 29.28
# Peso Real: 30.7, Peso Predito: 27.42
# Peso Real: 22.55, Peso Predito: 23.15
# Peso Real: 22.55, Peso Predito: 26.36
# Peso Real: 29.8, Peso Predito: 26.52
# Peso Real: 35.3, Peso Predito: 27.20
# Peso Real: 33.6, Peso Predito: 27.36
# Peso Real: 16.7, Peso Predito: 22.66
# Peso Real: 20.05, Peso Predito: 27.82
# Peso Real: 13.9, Peso Predito: 23.97
# Fold: 4, MSE: 91.73, RMSE: 9.58, MAE: 8.31, R2: 0.18, R: 0.70
# Fold 5:
#  - Treino: 34 C1, 46 C2
#  - Teste: 8 C1, 11 C2
# Peso Real: 7.1, Peso Predito: 23.09
# Peso Real: 12.55, Peso Predito: 20.33
# Peso Real: 30.55, Peso Predito: 30.19
# Peso Real: 29.7, Peso Predito: 30.14
# Peso Real: 41.4, Peso Predito: 30.58
# Peso Real: 14.3, Peso Predito: 28.60
# Peso Real: 27.5, Peso Predito: 29.53
# Peso Real: 14.9, Peso Predito: 28.79
# Peso Real: 28.55, Peso Predito: 28.64
# Peso Real: 32.75, Peso Predito: 28.94
# Peso Real: 31.0, Peso Predito: 30.22
# Peso Real: 35.9, Peso Predito: 31.64
# Peso Real: 6.8, Peso Predito: 20.96
# Peso Real: 33.25, Peso Predito: 23.82
# Peso Real: 27.55, Peso Predito: 24.71
# Peso Real: 30.4, Peso Predito: 22.82
# Peso Real: 23.25, Peso Predito: 31.17
# Peso Real: 22.25, Peso Predito: 26.45
# Peso Real: 13.65, Peso Predito: 28.83
# Fold: 5, MSE: 80.73, RMSE: 8.99, MAE: 7.15, R2: 0.15, R: 0.52
#
# Média dos resultados para Lasso:
# MSE: 92.23 ± 30.02
# RMSE: 9.49 ± 1.45
# MAE: 8.02 ± 0.95
# R2: 0.17 ± 0.01
# R: 0.58 ± 0.09
#
# Regressão com ElasticNet:
# Fold 1:
#  - Treino: 34 C1, 45 C2
#  - Teste: 8 C1, 12 C2
# Peso Real: 29.85, Peso Predito: 26.09
# Peso Real: 40.25, Peso Predito: 26.22
# Peso Real: 5.6, Peso Predito: 21.49
# Peso Real: 11.85, Peso Predito: 23.04
# Peso Real: 35.0, Peso Predito: 28.96
# Peso Real: 17.2, Peso Predito: 23.74
# Peso Real: 11.8, Peso Predito: 23.61
# Peso Real: 35.65, Peso Predito: 27.76
# Peso Real: 42.65, Peso Predito: 27.47
# Peso Real: 31.6, Peso Predito: 25.95
# Peso Real: 15.95, Peso Predito: 27.80
# Peso Real: 33.5, Peso Predito: 29.05
# Peso Real: 9.45, Peso Predito: 21.77
# Peso Real: 33.0, Peso Predito: 25.41
# Peso Real: 32.6, Peso Predito: 25.17
# Peso Real: 27.3, Peso Predito: 26.94
# Peso Real: 31.0, Peso Predito: 25.98
# Peso Real: 13.2, Peso Predito: 22.13
# Peso Real: 25.2, Peso Predito: 25.63
# Peso Real: 62.1, Peso Predito: 26.53
# Fold: 1, MSE: 146.35, RMSE: 12.10, MAE: 9.60, R2: 0.18, R: 0.69
# Fold 2:
#  - Treino: 34 C1, 45 C2
#  - Teste: 8 C1, 12 C2
# Peso Real: 17.4, Peso Predito: 27.77
# Peso Real: 21.2, Peso Predito: 26.01
# Peso Real: 30.1, Peso Predito: 29.86
# Peso Real: 20.0, Peso Predito: 26.05
# Peso Real: 30.65, Peso Predito: 28.48
# Peso Real: 21.65, Peso Predito: 29.84
# Peso Real: 34.65, Peso Predito: 31.17
# Peso Real: 32.2, Peso Predito: 28.64
# Peso Real: 36.65, Peso Predito: 28.79
# Peso Real: 16.55, Peso Predito: 25.74
# Peso Real: 33.8, Peso Predito: 29.17
# Peso Real: 15.4, Peso Predito: 25.32
# Peso Real: 41.0, Peso Predito: 28.41
# Peso Real: 11.0, Peso Predito: 20.44
# Peso Real: 36.0, Peso Predito: 24.64
# Peso Real: 33.6, Peso Predito: 24.32
# Peso Real: 34.8, Peso Predito: 27.11
# Peso Real: 44.2, Peso Predito: 26.30
# Peso Real: 15.8, Peso Predito: 24.41
# Peso Real: 25.5, Peso Predito: 22.56
# Fold: 2, MSE: 72.75, RMSE: 8.53, MAE: 7.51, R2: 0.17, R: 0.45
# Fold 3:
#  - Treino: 33 C1, 46 C2
#  - Teste: 9 C1, 11 C2
# Peso Real: 33.2, Peso Predito: 28.92
# Peso Real: 29.15, Peso Predito: 24.06
# Peso Real: 38.25, Peso Predito: 27.37
# Peso Real: 27.8, Peso Predito: 25.18
# Peso Real: 30.4, Peso Predito: 24.94
# Peso Real: 35.2, Peso Predito: 31.02
# Peso Real: 40.45, Peso Predito: 27.99
# Peso Real: 35.75, Peso Predito: 30.84
# Peso Real: 35.3, Peso Predito: 27.55
# Peso Real: 29.9, Peso Predito: 26.62
# Peso Real: 11.45, Peso Predito: 22.10
# Peso Real: 31.4, Peso Predito: 27.55
# Peso Real: 27.0, Peso Predito: 27.27
# Peso Real: 7.5, Peso Predito: 20.24
# Peso Real: 31.9, Peso Predito: 25.51
# Peso Real: 17.5, Peso Predito: 26.44
# Peso Real: 35.2, Peso Predito: 26.93
# Peso Real: 31.7, Peso Predito: 24.70
# Peso Real: 12.9, Peso Predito: 25.13
# Peso Real: 34.4, Peso Predito: 25.75
# Fold: 3, MSE: 61.01, RMSE: 7.81, MAE: 7.00, R2: 0.25, R: 0.72
# Fold 4:
#  - Treino: 33 C1, 46 C2
#  - Teste: 9 C1, 11 C2
# Peso Real: 12.3, Peso Predito: 22.67
# Peso Real: 7.45, Peso Predito: 22.27
# Peso Real: 11.95, Peso Predito: 24.76
# Peso Real: 41.65, Peso Predito: 30.25
# Peso Real: 39.55, Peso Predito: 28.75
# Peso Real: 18.0, Peso Predito: 26.83
# Peso Real: 38.75, Peso Predito: 29.15
# Peso Real: 9.1, Peso Predito: 22.41
# Peso Real: 11.9, Peso Predito: 25.31
# Peso Real: 30.65, Peso Predito: 29.67
# Peso Real: 24.8, Peso Predito: 30.01
# Peso Real: 30.7, Peso Predito: 27.64
# Peso Real: 22.55, Peso Predito: 25.26
# Peso Real: 22.55, Peso Predito: 27.01
# Peso Real: 29.8, Peso Predito: 27.11
# Peso Real: 35.3, Peso Predito: 28.74
# Peso Real: 33.6, Peso Predito: 27.47
# Peso Real: 16.7, Peso Predito: 23.42
# Peso Real: 20.05, Peso Predito: 27.27
# Peso Real: 13.9, Peso Predito: 23.60
# Fold: 4, MSE: 80.44, RMSE: 8.97, MAE: 8.04, R2: 0.28, R: 0.87
# Fold 5:
#  - Treino: 34 C1, 46 C2
#  - Teste: 8 C1, 11 C2
# Peso Real: 7.1, Peso Predito: 20.36
# Peso Real: 12.55, Peso Predito: 20.60
# Peso Real: 30.55, Peso Predito: 29.43
# Peso Real: 29.7, Peso Predito: 28.71
# Peso Real: 41.4, Peso Predito: 28.47
# Peso Real: 14.3, Peso Predito: 25.42
# Peso Real: 27.5, Peso Predito: 29.97
# Peso Real: 14.9, Peso Predito: 24.35
# Peso Real: 28.55, Peso Predito: 28.78
# Peso Real: 32.75, Peso Predito: 30.92
# Peso Real: 31.0, Peso Predito: 31.20
# Peso Real: 35.9, Peso Predito: 29.69
# Peso Real: 6.8, Peso Predito: 23.72
# Peso Real: 33.25, Peso Predito: 25.48
# Peso Real: 27.55, Peso Predito: 26.77
# Peso Real: 30.4, Peso Predito: 25.38
# Peso Real: 23.25, Peso Predito: 26.42
# Peso Real: 22.25, Peso Predito: 27.76
# Peso Real: 13.65, Peso Predito: 26.61
# Fold: 5, MSE: 65.90, RMSE: 8.12, MAE: 6.32, R2: 0.31, R: 0.76
#
# Média dos resultados para ElasticNet:
# MSE: 85.29 ± 31.22
# RMSE: 9.11 ± 1.55
# MAE: 7.69 ± 1.11
# R2: 0.24 ± 0.06
# R: 0.70 ± 0.14
#
# Regressão com Ridge:
# Fold 1:
#  - Treino: 34 C1, 45 C2
#  - Teste: 8 C1, 12 C2
# Peso Real: 29.85, Peso Predito: 30.97
# Peso Real: 40.25, Peso Predito: 26.41
# Peso Real: 5.6, Peso Predito: 7.37
# Peso Real: 11.85, Peso Predito: 16.41
# Peso Real: 35.0, Peso Predito: 33.47
# Peso Real: 17.2, Peso Predito: 15.31
# Peso Real: 11.8, Peso Predito: 14.69
# Peso Real: 35.65, Peso Predito: 29.34
# Peso Real: 42.65, Peso Predito: 34.16
# Peso Real: 31.6, Peso Predito: 35.69
# Peso Real: 15.95, Peso Predito: 20.45
# Peso Real: 33.5, Peso Predito: 32.17
# Peso Real: 9.45, Peso Predito: 11.38
# Peso Real: 33.0, Peso Predito: 26.62
# Peso Real: 32.6, Peso Predito: 23.79
# Peso Real: 27.3, Peso Predito: 29.76
# Peso Real: 31.0, Peso Predito: 29.05
# Peso Real: 13.2, Peso Predito: 6.55
# Peso Real: 25.2, Peso Predito: 26.10
# Peso Real: 62.1, Peso Predito: 33.47
# Fold: 1, MSE: 68.92, RMSE: 8.30, MAE: 5.50, R2: 0.62, R: 0.83
# Fold 2:
#  - Treino: 34 C1, 45 C2
#  - Teste: 8 C1, 12 C2
# Peso Real: 17.4, Peso Predito: 33.07
# Peso Real: 21.2, Peso Predito: 26.21
# Peso Real: 30.1, Peso Predito: 35.44
# Peso Real: 20.0, Peso Predito: 21.71
# Peso Real: 30.65, Peso Predito: 30.93
# Peso Real: 21.65, Peso Predito: 25.04
# Peso Real: 34.65, Peso Predito: 36.05
# Peso Real: 32.2, Peso Predito: 25.43
# Peso Real: 36.65, Peso Predito: 31.62
# Peso Real: 16.55, Peso Predito: 19.76
# Peso Real: 33.8, Peso Predito: 28.43
# Peso Real: 15.4, Peso Predito: 23.59
# Peso Real: 41.0, Peso Predito: 27.75
# Peso Real: 11.0, Peso Predito: 8.87
# Peso Real: 36.0, Peso Predito: 30.77
# Peso Real: 33.6, Peso Predito: 30.51
# Peso Real: 34.8, Peso Predito: 33.89
# Peso Real: 44.2, Peso Predito: 33.51
# Peso Real: 15.8, Peso Predito: 18.14
# Peso Real: 25.5, Peso Predito: 22.26
# Fold: 2, MSE: 42.05, RMSE: 6.48, MAE: 5.11, R2: 0.52, R: 0.72
# Fold 3:
#  - Treino: 33 C1, 46 C2
#  - Teste: 9 C1, 11 C2
# Peso Real: 33.2, Peso Predito: 33.06
# Peso Real: 29.15, Peso Predito: 21.58
# Peso Real: 38.25, Peso Predito: 28.59
# Peso Real: 27.8, Peso Predito: 22.31
# Peso Real: 30.4, Peso Predito: 24.74
# Peso Real: 35.2, Peso Predito: 33.98
# Peso Real: 40.45, Peso Predito: 38.47
# Peso Real: 35.75, Peso Predito: 33.98
# Peso Real: 35.3, Peso Predito: 38.86
# Peso Real: 29.9, Peso Predito: 21.91
# Peso Real: 11.45, Peso Predito: 11.83
# Peso Real: 31.4, Peso Predito: 31.64
# Peso Real: 27.0, Peso Predito: 39.49
# Peso Real: 7.5, Peso Predito: 5.83
# Peso Real: 31.9, Peso Predito: 29.97
# Peso Real: 17.5, Peso Predito: 20.97
# Peso Real: 35.2, Peso Predito: 26.05
# Peso Real: 31.7, Peso Predito: 23.65
# Peso Real: 12.9, Peso Predito: 22.75
# Peso Real: 34.4, Peso Predito: 32.20
# Fold: 3, MSE: 36.15, RMSE: 6.01, MAE: 4.72, R2: 0.55, R: 0.78
# Fold 4:
#  - Treino: 33 C1, 46 C2
#  - Teste: 9 C1, 11 C2
# Peso Real: 12.3, Peso Predito: 14.16
# Peso Real: 7.45, Peso Predito: 10.16
# Peso Real: 11.95, Peso Predito: 19.28
# Peso Real: 41.65, Peso Predito: 37.99
# Peso Real: 39.55, Peso Predito: 25.34
# Peso Real: 18.0, Peso Predito: 23.28
# Peso Real: 38.75, Peso Predito: 35.77
# Peso Real: 9.1, Peso Predito: 9.11
# Peso Real: 11.9, Peso Predito: 18.14
# Peso Real: 30.65, Peso Predito: 36.59
# Peso Real: 24.8, Peso Predito: 28.71
# Peso Real: 30.7, Peso Predito: 36.52
# Peso Real: 22.55, Peso Predito: 27.89
# Peso Real: 22.55, Peso Predito: 34.10
# Peso Real: 29.8, Peso Predito: 32.43
# Peso Real: 35.3, Peso Predito: 24.08
# Peso Real: 33.6, Peso Predito: 37.48
# Peso Real: 16.7, Peso Predito: 16.64
# Peso Real: 20.05, Peso Predito: 28.69
# Peso Real: 13.9, Peso Predito: 17.53
# Fold: 4, MSE: 41.88, RMSE: 6.47, MAE: 5.34, R2: 0.63, R: 0.82
# Fold 5:
#  - Treino: 34 C1, 46 C2
#  - Teste: 8 C1, 11 C2
# Peso Real: 7.1, Peso Predito: -1.06
# Peso Real: 12.55, Peso Predito: 8.77
# Peso Real: 30.55, Peso Predito: 32.07
# Peso Real: 29.7, Peso Predito: 30.78
# Peso Real: 41.4, Peso Predito: 34.59
# Peso Real: 14.3, Peso Predito: 13.91
# Peso Real: 27.5, Peso Predito: 30.01
# Peso Real: 14.9, Peso Predito: 13.92
# Peso Real: 28.55, Peso Predito: 24.95
# Peso Real: 32.75, Peso Predito: 35.63
# Peso Real: 31.0, Peso Predito: 42.24
# Peso Real: 35.9, Peso Predito: 35.09
# Peso Real: 6.8, Peso Predito: 13.91
# Peso Real: 33.25, Peso Predito: 23.34
# Peso Real: 27.55, Peso Predito: 28.31
# Peso Real: 30.4, Peso Predito: 27.81
# Peso Real: 23.25, Peso Predito: 28.38
# Peso Real: 22.25, Peso Predito: 29.95
# Peso Real: 13.65, Peso Predito: 19.46
# Fold: 5, MSE: 29.56, RMSE: 5.44, MAE: 4.36, R2: 0.69, R: 0.86
#
# Média dos resultados para Ridge:
# MSE: 43.71 ± 13.41
# RMSE: 6.54 ± 0.96
# MAE: 5.01 ± 0.42
# R2: 0.60 ± 0.06
# R: 0.80 ± 0.05
# Resultados salvos em 'regression_results_256_padding_seg_alci_will_stratified.xlsx'.
