# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import *
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from scipy.stats import pearsonr
from sklearn.model_selection import StratifiedKFold

# Importar modelos e suas respectivas funções preprocess_input
from tensorflow.keras.applications.xception import Xception, preprocess_input as preprocess_xception
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input as preprocess_vgg16
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input as preprocess_vgg19
from tensorflow.keras.applications.resnet import ResNet50, ResNet101, ResNet152, preprocess_input as preprocess_resnet
from tensorflow.keras.applications.resnet_v2 import ResNet50V2, ResNet101V2, ResNet152V2, preprocess_input as preprocess_resnet_v2
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input as preprocess_inception_v3
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input as preprocess_inception_resnet_v2
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input as preprocess_mobilenet
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input as preprocess_mobilenet_v2
from tensorflow.keras.applications.densenet import DenseNet121, DenseNet169, DenseNet201, preprocess_input as preprocess_densenet
from tensorflow.keras.applications.nasnet import NASNetMobile, NASNetLarge, preprocess_input as preprocess_nasnet
from tensorflow.keras.applications.efficientnet import EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetB4, EfficientNetB5, EfficientNetB6, EfficientNetB7, preprocess_input as preprocess_efficientnet
# Add EfficientNetV2 imports if available in your TensorFlow version
# from tensorflow.keras.applications.efficientnet_v2 import ...

# Definição do tamanho de entrada para cada modelo de CNN
model_input_sizes = {
    'Xception': (1024, 1024), #1
    'VGG16': (1024, 1024), #2
    'VGG19': (1024, 1024), #3 
    'ResNet50': (1024, 1024), #4 
    'ResNet50V2': (1024, 1024), #5 
    'ResNet101': (1024, 1024), #6 
    'ResNet101V2': (1024, 1024), #7 
    'ResNet152': (1024, 1024), #8
    'ResNet152V2': (1024, 1024), #9
    'InceptionV3': (1024, 1024), #10 
    'InceptionResNetV2': (1024, 1024), #11
    'MobileNet': (1024, 1024), #12 
    'MobileNetV2': (1024, 1024), #13
    'DenseNet121': (1024, 1024), #14
    'DenseNet169': (1024, 1024), #15
    'DenseNet201': (1024, 1024), #16 
    #'NASNetMobile': (224, 224), #17
    #'NASNetLarge': (331, 331), #18 
    'EfficientNetB0': (1024, 1024), #19
    'EfficientNetB1': (1024, 1024), #20
    'EfficientNetB2': (1024, 1024), #21
    'EfficientNetB3': (1024, 1024), #22
    'EfficientNetB4': (1024, 1024), #23
    'EfficientNetB5': (1024, 1024), #24
    'EfficientNetB6': (1024, 1024), #25
    'EfficientNetB7': (1024, 1024), #26
    # Add sizes for EfficientNetV2 models if needed
}

model_info = {
    'Xception': (Xception, preprocess_xception),
    'VGG16': (VGG16, preprocess_vgg16),
    'VGG19': (VGG19, preprocess_vgg19), #3
    'ResNet50': (ResNet50, preprocess_resnet), #4
    'ResNet50V2': (ResNet50V2, preprocess_resnet_v2), #5
    'ResNet101': (ResNet101, preprocess_resnet), #6
    'ResNet101V2': (ResNet101V2, preprocess_resnet_v2), #7
    'ResNet152': (ResNet152, preprocess_resnet), #8
    'ResNet152V2': (ResNet152V2, preprocess_resnet_v2), #9
    'InceptionV3': (InceptionV3, preprocess_inception_v3), #10
    'InceptionResNetV2': (InceptionResNetV2, preprocess_inception_resnet_v2), #11
    'MobileNet': (MobileNet, preprocess_mobilenet), #12
    'MobileNetV2': (MobileNetV2, preprocess_mobilenet_v2), #13
    'DenseNet121': (DenseNet121, preprocess_densenet), #14
    'DenseNet169': (DenseNet169, preprocess_densenet), #15
    'DenseNet201': (DenseNet201, preprocess_densenet), #16
    #'NASNetMobile': (NASNetMobile, preprocess_nasnet), #17
    #'NASNetLarge': (NASNetLarge, preprocess_nasnet), #18
    'EfficientNetB0': (EfficientNetB0, preprocess_efficientnet), #19
    'EfficientNetB1': (EfficientNetB1, preprocess_efficientnet), #20
    'EfficientNetB2': (EfficientNetB2, preprocess_efficientnet), #21
    'EfficientNetB3': (EfficientNetB3, preprocess_efficientnet), #22
    'EfficientNetB4': (EfficientNetB4, preprocess_efficientnet), #23
    'EfficientNetB5': (EfficientNetB5, preprocess_efficientnet), #24
    'EfficientNetB6': (EfficientNetB6, preprocess_efficientnet), #25
    'EfficientNetB7': (EfficientNetB7, preprocess_efficientnet), #26
}

# Função para preprocessar imagem
def preprocess_image(img_path, model_name):
    target_size = model_input_sizes[model_name]
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    preprocess_input_func = model_info[model_name][1]
    return preprocess_input_func(img_array_expanded_dims)

# Inicializar modelo
def init_model(model_name):
    model_class = model_info[model_name][0]
    model = model_class(weights='imagenet', include_top=False, pooling='avg')
    return model

# Extrair características
def extract_features(model, img_path, model_name):
    preprocessed_img = preprocess_image(img_path, model_name)
    features = model.predict(preprocessed_img)
    return features.flatten()

# Função para executar K-Fold de forma estratificada
def run_stratified_kfold_regressions(X, y, group_labels, model_cnn):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    models = [
        ('Linear Regression', LinearRegression()),
        ('Random Forest', RandomForestRegressor(random_state=42)),
        ('SVR', SVR()),
        ('Lasso', Lasso(random_state=42)),
        ('ElasticNet', ElasticNet(random_state=42)),
        ('Ridge', Ridge(random_state=42))
    ]
    
    all_results = []
    
    for name, model in models:
        mse_scores, rmse_scores, mae_scores, r2_scores, r_scores = [], [], [], [], []
        print(f"\nRegressão com {name}:")
        fold_number = 1
        for train_index, test_index in skf.split(X, group_labels):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            
            # Verificar a distribuição de C1 e C2 em cada fold
            train_labels = group_labels[train_index]
            test_labels = group_labels[test_index]
            print(f"Fold {fold_number}:")
            print(f" - Treino: {sum(train_labels == 'C1')} C1, {sum(train_labels == 'C2')} C2")
            print(f" - Teste: {sum(test_labels == 'C1')} C1, {sum(test_labels == 'C2')} C2")
            
            fold_number += 1

            # Treinar o modelo e fazer previsões
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            mse = mean_squared_error(y_test, y_pred)
            rmse = np.sqrt(mse)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)
            r = pearsonr(y_test, y_pred)[0] if np.var(y_pred) > 0 else 0
            
            mse_scores.append(mse)
            rmse_scores.append(rmse)
            mae_scores.append(mae)
            r2_scores.append(r2)
            r_scores.append(r)

            for real, pred in zip(y_test, y_pred):
                print(f"Peso Real: {real}, Peso Predito: {pred:.2f}")

            print(f"Fold: {len(mse_scores)}, MSE: {mse:.2f}, RMSE: {rmse:.2f}, MAE: {mae:.2f}, R2: {r2:.2f}, R: {r:.2f}")

        print(f"\nMédia dos resultados para {name}:")
        print(f"MSE: {np.mean(mse_scores):.2f} ± {np.std(mse_scores):.2f}")
        print(f"RMSE: {np.mean(rmse_scores):.2f} ± {np.std(rmse_scores):.2f}")
        print(f"MAE: {np.mean(mae_scores):.2f} ± {np.std(mae_scores):.2f}")
        print(f"R2: {np.mean(r2_scores):.2f} ± {np.std(r2_scores):.2f}")
        print(f"R: {np.mean(r_scores):.2f} ± {np.std(r_scores):.2f}")

        all_results.append({
            'REGRESSAO': name,
            'MSE': f"{np.mean(mse_scores):.2f} ± {np.std(mse_scores):.2f}",
            'RMSE': f"{np.mean(rmse_scores):.2f} ± {np.std(rmse_scores):.2f}",
            'MAE': f"{np.mean(mae_scores):.2f} ± {np.std(mae_scores):.2f}",
            'R2': f"{np.mean(r2_scores):.2f} ± {np.std(r2_scores):.2f}",
            'R': f"{np.mean(r_scores):.2f} ± {np.std(r_scores):.2f}",
            'CNN': model_cnn
        })
        
    return all_results

# Carregar dados
df = pd.read_csv('all_animal_images.csv')

# Adicionar uma nova coluna que identifica se o animal é do grupo C1 ou C2
df['Group'] = df['ID Animal'].apply(lambda x: 'C1' if 'C1_' in x else 'C2')

# Processar imagens e características para cada modelo
final_results = []
for model_name in model_info.keys():
    print(f"\nIniciando processamento com modelo: {model_name}")
    model = init_model(model_name)
    feature_dict = {}
    
    for index, row in df.iterrows():
        animal_id = row['ID Animal']
        img_path = row['Path']
        features = extract_features(model, img_path, model_name)
        if animal_id not in feature_dict:
            feature_dict[animal_id] = []
        feature_dict[animal_id].append(features)
        print(f"Características extraídas para ID {animal_id} da imagem {img_path}")

    for animal_id, feats in feature_dict.items():
        aggregate_features = np.mean(feats, axis=0)
        feature_dict[animal_id] = aggregate_features
        print(f"Vetor de características agregado para ID {animal_id}: {aggregate_features.shape}")

    feature_df = pd.DataFrame.from_dict(feature_dict, orient='index')
    weights = df[['ID Animal', 'Peso', 'Group']].drop_duplicates().set_index('ID Animal')
    feature_df = feature_df.join(weights)

    X = feature_df.iloc[:, :-2].values
    y = feature_df['Peso'].values
    group_labels = feature_df['Group'].values

    results = run_stratified_kfold_regressions(X, y, group_labels, model_name)
    final_results.extend(results)

# Criar DataFrame e salvar em Excel
results_df = pd.DataFrame(final_results)
results_df.to_excel('regression_results_1024_padding_seg_alci_will_stratified.xlsx', index=False)
print("Resultados salvos em 'regression_results_1024_padding_seg_alci_will_stratified.xlsx'.")
# Out:
# Iniciando processamento com modelo: Xception
# 1/1 [==============================] - 2s 2s/step
# Características extraídas para ID C2_01 da imagem base_alci_auto_seg\C2_01\roi_image_3851_left_bottom_png.rf.1e10cd3c3687b0bde4232dadd025e19d.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2_01 da imagem base_alci_auto_seg\C2_01\roi_image_3852_left_bottom_png.rf.09aa6b3620adc9bb43686a41a331e42f.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2_01 da imagem base_alci_auto_seg\C2_01\roi_image_3853_left_bottom_png.rf.9b91d1e91dd82065536609663734de31.jpg
# 1/1 [==============================] - 0s 29ms/step
# Características extraídas para ID C2_01 da imagem base_alci_auto_seg\C2_01\roi_image_3854_left_bottom_png.rf.675ab759862e944ded5d8d9de3a5783e.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2_02 da imagem base_alci_auto_seg\C2_02\roi_image_9630_left_bottom_png.rf.05cafdc06d98b26428a4e5a885e0da85.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2_02 da imagem base_alci_auto_seg\C2_02\roi_image_9631_left_bottom_png.rf.4b5d8238a2056edbcf606d04a8020a72.jpg
# 1/1 [==============================] - 0s 29ms/step
# Características extraídas para ID C2_02 da imagem base_alci_auto_seg\C2_02\roi_image_9632_left_bottom_png.rf.8d31e11d5244238e5465981c067f0d0e.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_02 da imagem base_alci_auto_seg\C2_02\roi_image_9633_left_bottom_png.rf.7b01c7a0bc77eaa296591d92a6e1e5ba.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_02 da imagem base_alci_auto_seg\C2_02\roi_image_9634_left_bottom_png.rf.7445c1f5aa6cb4a8c03be861463a0ee6.jpg
# 1/1 [==============================] - 0s 25ms/step
# Características extraídas para ID C2_02 da imagem base_alci_auto_seg\C2_02\roi_image_9635_left_bottom_png.rf.6347549e823e0b88623a98a2890e37fa.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_02 da imagem base_alci_auto_seg\C2_02\roi_image_9636_left_bottom_png.rf.7de20d278a77b75cd9cd6058cf58bbdb.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_02 da imagem base_alci_auto_seg\C2_02\roi_image_9637_left_bottom_png.rf.c62948bc5d7fa8b080d68e32ee6384f8.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_03 da imagem base_alci_auto_seg\C2_03\roi_image_0741_left_bottom_png.rf.3fc85ab54f86d9b3dde91462844dc470.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_03 da imagem base_alci_auto_seg\C2_03\roi_image_0742_left_bottom_png.rf.1ceaabd3e8acd81f5bc8aa6175d9b70e.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2_03 da imagem base_alci_auto_seg\C2_03\roi_image_0743_left_bottom_png.rf.0c898b167ac58da684323989dbc7953c.jpg
# 1/1 [==============================] - 0s 28ms/step
# Características extraídas para ID C2_03 da imagem base_alci_auto_seg\C2_03\roi_image_0744_left_bottom_png.rf.313ba8008d147ef57cd6c7ec38fd1505.jpg
# 1/1 [==============================] - 0s 29ms/step
# Características extraídas para ID C2_03 da imagem base_alci_auto_seg\C2_03\roi_image_0745_left_bottom_png.rf.c7418f4ff56f8b710c3367daee5b3a27.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2_03 da imagem base_alci_auto_seg\C2_03\roi_image_0746_left_bottom_png.rf.579bc52bf021d17973be4dd802f52637.jpg
# 1/1 [==============================] - 0s 25ms/step
# Características extraídas para ID C2_03 da imagem base_alci_auto_seg\C2_03\roi_image_0747_left_bottom_png.rf.a6004fc21cb40e90f0f97a25e6aa7782.jpg
# 1/1 [==============================] - 0s 28ms/step
# Características extraídas para ID C2_03 da imagem base_alci_auto_seg\C2_03\roi_image_0748_left_bottom_png.rf.d46eee2b7853445bb30c2e0bad510e71.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2
ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4103_left_bottom_png.rf.b3d4ecc12c2b36bc55f33bbb56f20b46.jpg
# 1/1 [==============================] - 0s 25ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4104_left_bottom_png.rf.d17dd8244ef8f9994265611a7108bde0.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4105_left_bottom_png.rf.1d1b77d8d7a7ae5362e28a153fd56094.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4106_left_bottom_png.rf.b062d6352a37e1f7fa3259376b61e26f.jpg
# 1/1 [==============================] - 0s 27ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4107_left_bottom_png.rf.13da36de96eda7f85e4259369b37b344.jpg
# 1/1 [==============================] - 0s 25ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4108_left_bottom_png.rf.e5c8d37f57010ea95dcee7cab43cdb94.jpg
# 1/1 [==============================] - 0s 25ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4109_left_bottom_png.rf.2737bede4a512f38f0de6b380ebe3f48.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4110_left_bottom_png.rf.2d612490d1300d3edf7c7635ab3bf3d3.jpg
# 1/1 [==============================] - 0s 25ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4111_left_bottom_png.rf.d9bf2fa27d1b31164891deb1c92fefae.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_13 da imagem base_alci_auto_seg\C2_13\roi_image_4112_left_bottom_png.rf.7956ba7a32252a84a47f4fc75b21d644.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_14 da imagem base_alci_auto_seg\C2_14\roi_image_12413_left_bottom_png.rf.17cf10bcdeaed73766a9b070baeb151a.jpg
# 1/1 [==============================] - 0s 28ms/step
# Características extraídas para ID C2_14 da imagem base_alci_auto_seg\C2_14\roi_image_12414_left_bottom_png.rf.4d071244908708bd64f331a9367fb9a2.jpg
# 1/1 [==============================] - 0s 26ms/step
# Características extraídas para ID C2_14 da imagem base_alci_auto_seg\C2_14\roi_image_12415_left_bottom_png.rf.f7bdaa9bf51a161e16ff2e8d7cd901ea.jpg
# 1/1 [==============================] - 0s 25ms/step
# Características extraídas para ID C2_14 da imagem base_alci_auto_seg\C2_14\roi_image_12416_left_bottom_png.rf.48a4b86800afdd5a7b65f9e218fc6167.jpg
# 1/1 [==============================] - 0s 24ms/step
# Características extraídas para ID C2_14 da imagem base_alci_auto_seg\C2_14\roi_image_12417_left_bottom_png.rf.c06bdac2ebb79b150016e922fcea54d3.jpg
# 1/1 [==============================] - 0s 27ms/step
# ...
# 1/1 [==============================] - 0s 113ms/step
# Características extraídas para ID C2_59 da imagem base_alci_auto_seg\C2_59\roi_image_0964_left_bottom_png.rf.24af7b757e8b1fe2741cc28a07b768be.jpg
# 1/1 [==============================] - 0s 104ms/step
# Características extraídas para ID C2_59 da imagem base_alci_auto_seg\C2_59\roi_image_0965_left_bottom_png.rf.76fff02ca063a6c28073b76f10472b93.jpg
# 1/1 [==============================] - 0s 114ms/step
# Características extraídas para ID C2_60 da imagem base_alci_auto_seg\C2_60\roi_image_0668_left_bottom_png.rf.4ed4c173bc9bfe80134c2b5669501ebe.jpg
# 1/1 [==============================] - 0s 116ms/step
# Características extraídas para ID C2_60 da imagem base_alci_auto_seg\C2_60\roi_image_0669_left_bottom_png.rf.070c64a0b28c7bdc40efaab84649276a.jpg
# 1/1 [==============================] - 0s 110ms/step
# Características extraídas para ID C2_60 da imagem base_alci_auto_seg\C2_60\roi_image_0670_left_bottom_png.rf.ba3aa22bae0d44a995af1ce6a0f3acab.jpg
# 1/1 [==============================] - 0s 104ms/step
# Características extraídas para ID C2_60 da imagem base_alci_auto_seg\C2_60\roi_image_0671_left_bottom_png.rf.b440dc0473afdacbc79148e0323e92b9.jpg
# 1/1 [==============================] - 0s 115ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0546_left_bottom_png.rf.4012363fce300bc137e02152f2f30f42.jpg
# 1/1 [==============================] - 0s 102ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0547_left_bottom_png.rf.0bec2a91c5accc5544e391b4a33cd88c.jpg
# 1/1 [==============================] - 0s 105ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0548_left_bottom_png.rf.ce17a6e6968db78adcebf8248022607f.jpg
# 1/1 [==============================] - 0s 112ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0549_left_bottom_png.rf.5f5003f3d50454e57c4c50ab12412b5b.jpg
# 1/1 [==============================] - 0s 111ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0550_left_bottom_png.rf.a01098b089cf9db716f4a71dc366fd1f.jpg
# 1/1 [==============================] - 0s 101ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0551_left_bottom_png.rf.8be65424301f2dbc9065ff27ef89ee2c.jpg
# 1/1 [==============================] - 0s 109ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0552_left_bottom_png.rf.fc3c3270b3cce899abf8705a92a7e8f7.jpg
# 1/1 [==============================] - 0s 107ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0553_left_bottom_png.rf.9309e10e916897447e05161d744c5b62.jpg
# 1/1 [==============================] - 0s 105ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0554_left_bottom_png.rf.0ed9b000a5452efac80397f690610435.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C2_61 da imagem base_alci_auto_seg\C2_61\roi_image_0555_left_bottom_png.rf.6dbab3e2c94541583f1f9c4bd387e5f7.jpg
# 1/1 [==============================] - 0s 112ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0576_left_bottom_png.rf.bab740ff1980081752b24b79f840967e.jpg
# 1/1 [==============================] - 0s 112ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0577_left_bottom_png.rf.8679ae3f2eb7b936bf4408c73feb9bf4.jpg
# 1/1 [==============================] - 0s 104ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0578_left_bottom_png.rf.3372e0743aea721fc98212fafd9e58ab.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0579_left_bottom_png.rf.a93c739f82d4ee85976be709a970de86.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0580_left_bottom_png.rf.e02a4f05f5ec3eaf289860d0104b8077.jpg
# 1/1 [==============================] - 0s 106ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0581_left_bottom_png.rf.c5a5b8a8324413cd8d1bcf747861dc22.jpg
# 1/1 [==============================] - 0s 99ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0582_left_bottom_png.rf.c4e6242bbc98b3cea3031d58a8d82d68.jpg
# 1/1 [==============================] - 0s 107ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0583_left_bottom_png.rf.4e9b164e3f137633a304d7a35dc00618.jpg
# 1/1 [==============================] - 0s 100ms/step
# Características extraídas para ID C2_62 da imagem base_alci_auto_seg\C2_62\roi_image_0584_left_bottom_png.rf.a8405f1ebb6af3aaa7b6644e748ca234.jpg
# 1/1 [==============================] - 0s 104ms/step
# Características extraídas para ID C2_63 da imagem base_alci_auto_seg\C2_63\roi_image_1037_left_bottom_png.rf.f7ae0ee953c31b43ef9aa7a2e56ae9a5.jpg
# 1/1 [==============================] - 0s 101ms/step
# Características extraídas para ID C2_63 da imagem base_alci_auto_seg\C2_63\roi_image_1038_left_bottom_png.rf.6dbc15333e7f83ad12608f18be01eab6.jpg
# 1/1 [==============================] - 0s 113ms/step
# Características extraídas para ID C2_63 da imagem base_alci_auto_seg\C2_63\roi_image_1039_left_bottom_png.rf.b5a1e5a87f7c0ef2b52f09cbaf4aa88d.jpg
# 1/1 [==============================] - 0s 118ms/step
# Características extraídas para ID C2_63 da imagem base_alci_auto_seg\C2_63\roi_image_1040_left_bottom_png.rf.15802fbeecb18931ad70871e3b532f12.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C2_63 da imagem base_alci_auto_seg\C2_63\roi_image_1041_left_bottom_png.rf.0822730c4a590f604f7147b48d3950b5.jpg
# 1/1 [==============================] - 0s 113ms/step
# Características extraídas para ID C2_63 da imagem base_alci_auto_seg\C2_63\roi_image_1042_left_bottom_png.rf.0955c0bce62af7a446a4eab2a431a9b5.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C2_64 da imagem base_alci_auto_seg\C2_64\roi_image_1211_left_bottom_png.rf.cd4e10845034c8c667eb437921253983.jpg
# 1/1 [==============================] - 0s 105ms/step
# Características extraídas para ID C2_64 da imagem base_alci_auto_seg\C2_64\roi_image_1212_left_bottom_png.rf.77a655ffd7925f31e087fcc2d4263a3f.jpg
# 1/1 [==============================] - 0s 100ms/step
# Características extraídas para ID C2_64 da imagem base_alci_auto_seg\C2_64\roi_image_1213_left_bottom_png.rf.17241f2616ab069deccfea9b44535165.jpg
# 1/1 [==============================] - 0s 107ms/step
# Características extraídas para ID C2_64 da imagem base_alci_auto_seg\C2_64\roi_image_1214_left_bottom_png.rf.46fa0913fe3ac29bd5f30fa915049f1a.jpg
# 1/1 [==============================] - 0s 109ms/step
# Características extraídas para ID C2_64 da imagem base_alci_auto_seg\C2_64\roi_image_1215_left_bottom_png.rf.04a66cf20a34a681065d27f30481692a.jpg
# 1/1 [==============================] - 0s 104ms/step
# Características extraídas para ID C2_64 da imagem base_alci_auto_seg\C2_64\roi_image_1216_left_bottom_png.rf.42888303e12fe8eb1c188f31bc88233f.jpg
# 1/1 [==============================] - 0s 101ms/step
# Características extraídas para ID C1_01 da imagem base_will_auto_seg\C1_01\roi_35_png.rf.561d4298863d85ef9065dead0c9dabbc.jpg
# 1/1 [==============================] - 0s 110ms/step
# Características extraídas para ID C1_01 da imagem base_will_auto_seg\C1_01\roi_36_png.rf.ccbecebd3f549a020b0f783b99f93f6b.jpg
# 1/1 [==============================] - 0s 101ms/step
# Características extraídas para ID C1_02 da imagem base_will_auto_seg\C1_02\roi_11_png.rf.1a8dac5cb937f5209928fccf79158416.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_02 da imagem base_will_auto_seg\C1_02\roi_12_png.rf.1ad79a92fa6dc766f574c261837a0b42.jpg
# 1/1 [==============================] - 0s 113ms/step
# Características extraídas para ID C1_02 da imagem base_will_auto_seg\C1_02\roi_17_png.rf.fec39d68e5262598b0d9b38a00bc95b8.jpg
# 1/1 [==============================] - 0s 105ms/step
# Características extraídas para ID C1_02 da imagem base_will_auto_seg\C1_02\roi_18_png.rf.b2087312170866237b9b169472f1ebfa.jpg
# 1/1 [==============================] - 0s 115ms/step
# Características extraídas para ID C1_02 da imagem base_will_auto_seg\C1_02\roi_34_png.rf.0aac1fd8d3e4a12ae877b6614798ad5e.jpg
# 1/1 [==============================] - 0s 109ms/step
# Características extraídas para ID C1_02 da imagem base_will_auto_seg\C1_02\roi_35_png.rf.e8d6f923916cf77ab11ab30404705273.jpg
# 1/1 [==============================] - 0s 102ms/step
# Características extraídas para ID C1_02 da imagem base_will_auto_seg\C1_02\roi_39_png.rf.fd15a41f0b6266778c2fe8f3ca8dfa5f.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_02 da imagem base_will_auto_seg\C1_02\roi_40_png.rf.1b475ded6cbb7980de5ea26e46f9d2bc.jpg
# 1/1 [==============================] - 0s 113ms/step
# Características extraídas para ID C1_03 da imagem base_will_auto_seg\C1_03\roi_11_png.rf.b3f16018ebdaccbf3089c488471b8e28.jpg
# 1/1 [==============================] - 0s 106ms/step
# Características extraídas para ID C1_03 da imagem base_will_auto_seg\C1_03\roi_12_png.rf.8bdd2cb3278cea390b65086db55d75b2.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_03 da imagem base_will_auto_seg\C1_03\roi_13_png.rf.6071965011786b1ce66b244a268e928f.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_03 da imagem base_will_auto_seg\C1_03\roi_14_png.rf.801716e6d5635d21ff8c80601098fff9.jpg
# 1/1 [==============================] - 0s 102ms/step
# Características extraídas para ID C1_03 da imagem base_will_auto_seg\C1_03\roi_15_png.rf.19e0ccf0643497587dae74458cfc36f7.jpg
# 1/1 [==============================] - 0s 111ms/step
# Características extraídas para ID C1_04 da imagem base_will_auto_seg\C1_04\roi_16_png.rf.ca0862ddcb9d45d05be22198dc13eb00.jpg
# 1/1 [==============================] - 0s 101ms/step
# Características extraídas para ID C1_05 da imagem base_will_auto_seg\C1_05\roi_16_png.rf.9ec4374f5905212c42495260b463b45b.jpg
# 1/1 [==============================] - 0s 105ms/step
# Características extraídas para ID C1_05 da imagem base_will_auto_seg\C1_05\roi_17_png.rf.3c97a23ed6a34ea340aed0911db169ee.jpg
# 1/1 [==============================] - 0s 110ms/step
# Características extraídas para ID C1_06 da imagem base_will_auto_seg\C1_06\roi_25_png.rf.979015f4d11b336d1ffb0b99da88c239.jpg
# 1/1 [==============================] - 0s 101ms/step
# Características extraídas para ID C1_06 da imagem base_will_auto_seg\C1_06\roi_26_png.rf.13792346d56c02e1d369a795ec71acab.jpg
# 1/1 [==============================] - 0s 111ms/step
# Características extraídas para ID C1_06 da imagem base_will_auto_seg\C1_06\roi_27_png.rf.bedb6f5486d78a6e5dba05928febfcd2.jpg
# 1/1 [==============================] - 0s 107ms/step
# Características extraídas para ID C1_07 da imagem base_will_auto_seg\C1_07\roi_12_png.rf.5d49bf10bbaafe969e020e2adb303d5f.jpg
# 1/1 [==============================] - 0s 109ms/step
# Características extraídas para ID C1_07 da imagem base_will_auto_seg\C1_07\roi_13_png.rf.4497792ae935ea064e5bddb5d80dc592.jpg
# 1/1 [==============================] - 0s 113ms/step
# Características extraídas para ID C1_07 da imagem base_will_auto_seg\C1_07\roi_16_png.rf.054c1582758c5a5f6d29f62c599fda97.jpg
# 1/1 [==============================] - 0s 125ms/step
# Características extraídas para ID C1_08 da imagem base_will_auto_seg\C1_08\roi_26_png.rf.a84abebcf8d243d7d0c43b42c2243f9c.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_09 da imagem base_will_auto_seg\C1_09\roi_55_png.rf.e90171e842b0b67525e6cd27f99a85a3.jpg
# 1/1 [==============================] - 0s 100ms/step
# Características extraídas para ID C1_09 da imagem base_will_auto_seg\C1_09\roi_56_png.rf.3c49ba59d92c9bcb75c2babf4962ee19.jpg
# 1/1 [==============================] - 0s 109ms/step
# Características extraídas para ID C1_09 da imagem base_will_auto_seg\C1_09\roi_57_png.rf.a4aec55c52ff09ea74251856927f48ad.jpg
# 1/1 [==============================] - 0s 110ms/step
# Características extraídas para ID C1_09 da imagem base_will_auto_seg\C1_09\roi_58_png.rf.a95a6fd2a674ff5f541be9fb8e49aff2.jpg
# 1/1 [==============================] - 0s 102ms/step
# Características extraídas para ID C1_09 da imagem base_will_auto_seg\C1_09\roi_59_png.rf.9a7d02805383dd129dceaec3ec72875e.jpg
# 1/1 [==============================] - 0s 111ms/step
# Características extraídas para ID C1_09 da imagem base_will_auto_seg\C1_09\roi_60_png.rf.2971b0398538120df139fceac63c000e.jpg
# 1/1 [==============================] - 0s 107ms/step
# Características extraídas para ID C1_10 da imagem base_will_auto_seg\C1_10\roi_16_png.rf.b179b2eb6826fc98f789e2ae32233d54.jpg
# 1/1 [==============================] - 0s 106ms/step
# Características extraídas para ID C1_11 da imagem base_will_auto_seg\C1_11\roi_13_png.rf.5d245ae72f4830770c4e400e656866fb.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_11 da imagem base_will_auto_seg\C1_11\roi_14_png.rf.8d8015eada2a19731260906d47468b64.jpg
# 1/1 [==============================] - 0s 101ms/step
# Características extraídas para ID C1_11 da imagem base_will_auto_seg\C1_11\roi_15_png.rf.12ce928c328fde8e7cf2e85d1f3db776.jpg
# 1/1 [==============================] - 0s 111ms/step
# Características extraídas para ID C1_11 da imagem base_will_auto_seg\C1_11\roi_16_png.rf.3563cde3e42be586710236e541e3aef5.jpg
# 1/1 [==============================] - 0s 102ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_23_png.rf.5b53dfaf40e14cda423dc8dec83351de.jpg
# 1/1 [==============================] - 0s 112ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_24_png.rf.e4bba433252f41c157616f2ea728f99b.jpg
# 1/1 [==============================] - 0s 111ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_25_png.rf.37448acfad522908954f4a66fc4f016d.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_26_png.rf.06c9828b0f75e7c3eb2dd747837f7b49.jpg
# 1/1 [==============================] - 0s 107ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_27_png.rf.2206748ea444bcde27019768973d6ee2.jpg
# 1/1 [==============================] - 0s 102ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_28_png.rf.d65788a9a824a97b5e442430aa40814b.jpg
# 1/1 [==============================] - 0s 100ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_29_png.rf.98126cc149ed1aeccf5fc8a032978358.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_30_png.rf.0bc96dc90a7d4d3269b58d63566daa30.jpg
# 1/1 [==============================] - 0s 102ms/step
# Características extraídas para ID C1_12 da imagem base_will_auto_seg\C1_12\roi_31_png.rf.99331f15c370ad14c78348bf34d708bc.jpg
# 1/1 [==============================] - 0s 113ms/step
# Características extraídas para ID C1_13 da imagem base_will_auto_seg\C1_13\roi_12_png.rf.6e69e1aefa1d66b1695175da988d68c4.jpg
# 1/1 [==============================] - 0s 108ms/step
# Características extraídas para ID C1_13 da imagem base_will_auto_seg\C1_13\roi_13_png.rf.9f23efb203dd9ece9bbd0eb6badf878d.jpg
# 1/1 [==============================] - 0s 106ms/step
# Características extraídas para ID C1_13 da imagem base_will_auto_seg\C1_13\roi_14_png.rf.b036f94ce281586766af44ecc64f1a28.jpg
